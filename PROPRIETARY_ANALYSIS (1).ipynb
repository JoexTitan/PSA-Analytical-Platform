# %% [markdown]
# ## **GETTING STARTED**

# %%
# !python --version
# !pip show spotipy
# !pip install spotipy
import warnings
warnings.filterwarnings('ignore')
# Out:
# Python 3.7.15
# WARNING: Package(s) not found: spotipy
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spotipy
#   Downloading spotipy-2.21.0-py3-none-any.whl (28 kB)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 17.7 MB/s
# Collecting redis>=3.5.3
#   Downloading redis-4.3.4-py3-none-any.whl (246 kB)
#      |████████████████████████████████| 246 kB 64.5 MB/s
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (1.15.0)
# Collecting requests>=2.25.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.5 MB/s
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (4.13.0)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging>=20.4 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (4.1.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.3->spotipy) (1.14.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.3->spotipy) (3.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.4->redis>=3.5.3->spotipy) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2022.9.24)
# Installing collected packages: urllib3, deprecated, requests, redis, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed deprecated-1.2.13 redis-4.3.4 requests-2.28.1 spotipy-2.21.0 urllib3-1.26.12

# %% [markdown]
# ## **AUTHORIZATION TO SPOTIFY API**

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

SPOTIPY_CLIENT_ID='a9c08768bf6f4d5083cdafbbf17c2277'
SPOTIPY_CLIENT_SECRET='445ef713ee2b40d19c9c5d178f6b2380'

# %%
auth_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
sp.me
# Out:
# <bound method Spotify.me of <spotipy.client.Spotify object at 0x7f7dccd0b750>>

# %% [markdown]
# ## **SEARCHING FOR ALBUMS**

# %%
albums = sp.search(q='album:'+'justice',type='album', limit=20)

# %%
len(albums['albums']['items'])
# Out:
# 20

# %%
albums['albums']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#   'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#   'id': '1uNFoZAHBGtllmzznpCI3s',
#   'name': 'Justin Bieber',
#   'type': 'artist',
#   'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}]

# %%
albums['albums']['items'][0]['artists'][0]['name']
# Out:
# 'Justin Bieber'

# %%
for i in range(20):
  print(albums['albums']['items'][i])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(20):
  print(albums['albums']['items'][i]['artists'][0]['name'])
# Out:
# Justin Bieber
# Metallica
# Justin Bieber
# Five Finger Death Punch
# Victorious Cast
# Metallica
# Justin Bieber
# Justin Bieber
# Justice
# Victorious Cast
# Justin Bieber
# Junkie XL
# Danny Elfman
# Five Finger Death Punch
# Hans Zimmer
# Various Artists
# William Murphy
# MGMT
# Justin Bieber
# Canton Jones

# %% [markdown]
# ## **SEARCHING FOR TRACKS**

# %%
tracks = sp.search(q='track:' + 'Ghost', type='track', limit = 20)

# %%
len(tracks['tracks']['items'])
# Out:
# 20

# %%
tracks['tracks']['items'][0]

# %%
for i in range(20):
  print(tracks['tracks']['items'][i])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(20):
  print(tracks['tracks']['items'][i]['artists'])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(20):
  print(tracks['tracks']['items'][i]['artists'][0]['name'])
# Out:
# Justin Bieber
# Kanye West
# Ray Parker Jr.
# Justin Bieber
# Benson Boone
# Sasha Alex Sloan
# 5 Seconds of Summer
# Confetti
# Teddy Hyde
# Harry Styles
# My Chemical Romance
# Mimi Webb
# 21 Savage
# Carrie Underwood
# Crumb
# Ray Parker Jr.
# Ryan Caraveo
# Mother Mother
# Lil Peep
# Lil Peep

# %%
if len(tracks['tracks']['items']) > 0:
  for item in tracks['tracks']['items']:
    print(f"Track Name: {item['name']}  ||  Author: {item['artists'][0]['name']}")
    print(f"Track ID: {item['id']}  ||  Author ID - {item['artists'][0]['id']}")
    print('--------------------------------------------------------------------------------------')
# Out:
# Track Name: Ghost  ||  Author: Justin Bieber
# Track ID: 6I3mqTwhRpn34SLVafSH7G  ||  Author ID - 1uNFoZAHBGtllmzznpCI3s
# --------------------------------------------------------------------------------------
# Track Name: Ghost Town  ||  Author: Kanye West
# Track ID: 7vgTNTaEz3CsBZ1N4YQalM  ||  Author ID - 5K4W6rqBFWDnAN6FQUkS6x
# --------------------------------------------------------------------------------------
# Track Name: Ghostbusters  ||  Author: Ray Parker Jr.
# Track ID: 569uHYIB0X324FZOBEhvit  ||  Author ID - 0NyzfcGDZZ6GM25EBG9BYK
# --------------------------------------------------------------------------------------
# Track Name: Ghost  ||  Author: Justin Bieber
# Track ID: 5dPz35akJjPqb17yeqNwqH  ||  Author ID - 1uNFoZAHBGtllmzznpCI3s
# --------------------------------------------------------------------------------------
# Track Name: GHOST TOWN  ||  Author: Benson Boone
# Track ID: 135Lf4Q0CzlMNfOxbEUsLH  ||  Author ID - 22wbnEMDvgVIAGdFeek6ET
# --------------------------------------------------------------------------------------
# Track Name: Dancing With Your Ghost  ||  Author: Sasha Alex Sloan
# Track ID: 1TQXIltqoZ5XXyfCbAeSQQ  ||  Author ID - 4xnihxcoXWK3UqryOSnbw5
# --------------------------------------------------------------------------------------
# Track Name: Ghost Of You  ||  Author: 5 Seconds of Summer
# Track ID: 1MhXdlCQPnO56T57MfmaRm  ||  Author ID - 5Rl15oVamLq7FbSb0NNBNy
# --------------------------------------------------------------------------------------
# Track Name: Ghost  ||  Author: Confetti
# Track ID: 30uCmqegKQnH5AbOE51gPD  ||  Author ID - 1oyUjl52ohRrCv3EL1UdpM
# --------------------------------------------------------------------------------------
# Track Name: Sex with a Ghost  ||  Author: Teddy Hyde
# Track ID: 1Y2583xYzwiEXDetAB7H1Q  ||  Author ID - 62DKpfVgNt372d3Zz6TRc7
# --------------------------------------------------------------------------------------
# Track Name: Two Ghosts  ||  Author: Harry Styles
# Track ID: 4B1rpPmQXwj78wk6aIGwwU  ||  Author ID - 6KImCVD70vtIoJWnq6nGn3
# --------------------------------------------------------------------------------------
# Track Name: The Ghost of You  ||  Author: My Chemical Romance
# Track ID: 1yKAqZoi8xWGLCf5vajroL  ||  Author ID - 7FBcuc1gsnv6Y1nwFtNRCb
# --------------------------------------------------------------------------------------
# Track Name: Ghost of You  ||  Author: Mimi Webb
# Track ID: 7Kbw2fTMOU43MrqXdGzroh  ||  Author ID - 3GxKJzJK4LpsYGXQrw77wz
# --------------------------------------------------------------------------------------
# Track Name: Ghostface Killers (feat. Travis Scott)  ||  Author: 21 Savage
# Track ID: 5u6vkDnOyaf8LsteDAj2ub  ||  Author ID - 1URnnhqYAYcrqrcwql10ft
# --------------------------------------------------------------------------------------
# Track Name: Ghost Story  ||  Author: Carrie Underwood
# Track ID: 2FGOg7uYBfnspkPOISXTFY  ||  Author ID - 4xFUf1FHVy696Q1JQZMTRj
# --------------------------------------------------------------------------------------
# Track Name: Ghostride  ||  Author: Crumb
# Track ID: 0R3TWpoxAhT3HDXM7tpRzS  ||  Author ID - 4kSGbjWGxTchKpIxXPJv0B
# --------------------------------------------------------------------------------------
# Track Name: Ghostbusters  ||  Author: Ray Parker Jr.
# Track ID: 3m0y8qLoznUYi73SUBP8GI  ||  Author ID - 0NyzfcGDZZ6GM25EBG9BYK
# --------------------------------------------------------------------------------------
# Track Name: Ghost  ||  Author: Ryan Caraveo
# Track ID: 7CHMY5TN1e8oqDnRwwJR61  ||  Author ID - 1PDE2MIJ4M6uvFJDrslazf
# --------------------------------------------------------------------------------------
# Track Name: Ghosting  ||  Author: Mother Mother
# Track ID: 3vZUC1m6QVm7urnN6lcF64  ||  Author ID - 0e86yPdC41PGRkLp2Q1Bph
# --------------------------------------------------------------------------------------
# Track Name: ghost girl  ||  Author: Lil Peep
# Track ID: 5LAVhynnTmj9VJjW8xGZdP  ||  Author ID - 2kCcBybjl3SAtIcwdWpUe3
# --------------------------------------------------------------------------------------
# Track Name: ghost boy  ||  Author: Lil Peep
# Track ID: 4AiFSXnVm0Bqecjdn3Brr8  ||  Author ID - 2kCcBybjl3SAtIcwdWpUe3
# --------------------------------------------------------------------------------------

# %% [markdown]
# ## **Audio Features Augmentation**

# %% [markdown]
# **Impactful Audio Feautures to Include:**
#
#
# *  *Acousticness*
# >* The confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence that the track is acoustic.
#
# *  *Danceability*
# >* Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# *  *Song Energy*
# >* Song energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# *  *Instrumentalness*
# >* Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# *  *Liveness*
# >* Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# *  *Loudness*
# >* The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
#
# *  *Speechiness*
# >* Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# *  *Valence*
# >* A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %%
track_audio_specs  = sp.audio_features('3yfqSUWxFvZELEM4PmlwIR')

# %%
track_audio_specs
# Out:
# [{'danceability': 0.949,
#   'energy': 0.661,
#   'key': 5,
#   'loudness': -4.244,
#   'mode': 0,
#   'speechiness': 0.0572,
#   'acousticness': 0.0302,
#   'instrumentalness': 0,
#   'liveness': 0.0454,
#   'valence': 0.76,
#   'tempo': 104.504,
#   'type': 'audio_features',
#   'id': '3yfqSUWxFvZELEM4PmlwIR',
#   'uri': 'spotify:track:3yfqSUWxFvZELEM4PmlwIR',
#   'track_href': 'https://api.spotify.com/v1/tracks/3yfqSUWxFvZELEM4PmlwIR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yfqSUWxFvZELEM4PmlwIR',
#   'duration_ms': 284200,
#   'time_signature': 4}]

# %%
import pandas as pd 
df = pd.DataFrame(track_audio_specs, index=[0])
df_audio_specs = df.loc[:,['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence']]

# %%
df_audio_specs
# Out:
#    danceability  energy  speechiness  acousticness  instrumentalness  \
# 0         0.949   0.661       0.0572        0.0302                 0
#
#    liveness  valence
# 0    0.0454     0.76

# %%
from matplotlib.colorbar import Colorbar
import numpy as np
import matplotlib.pyplot as plt

def feature_plot(features):
    labels= list(features)[:]
    stats= features.mean().tolist()

    angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)

    # close the plot
    stats=np.concatenate((stats,[stats[0]]))
    angles=np.concatenate((angles,[angles[0]]))

    #Size of the figure
    fig=plt.figure(figsize = (19,19), facecolor='w')

    ax = fig.add_subplot(221, polar=True)
    ax.plot(angles, stats, 'o-', linewidth=1.9, label = "Song Features", color= 'purple')
    ax.fill(angles, stats, alpha=0.25, facecolor='purple')
    ax.set_thetagrids(angles[0:7] * 180/np.pi, labels , fontsize = 13)


    ax.set_rlabel_position(250)
    plt.yticks([0.25 , 0.5 , 0.75 , 1], ["0.25",'0.5', "0.75", "1"], color="black", size=13)
    plt.ylim(0,1)

    plt.legend(loc='best', bbox_to_anchor=(0.095, 0.095))

# %%
feature_plot(df_audio_specs)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def feature_plot2(features1,features2):
    #Import Libraries for Feature plot
    import numpy as np
    import matplotlib.pyplot as plt
    
    labels= list(features1)[:]
    stats= features1.mean().tolist()
    stats2 = features2.mean().tolist()

    angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)

    # close the plot
    stats=np.concatenate((stats,[stats[0]]))
    stats2 =np.concatenate((stats2,[stats2[0]])) 
    angles=np.concatenate((angles,[angles[0]]))

    #Size of the figure
    fig=plt.figure(figsize = (18,18))

    ax = fig.add_subplot(221, polar=True)
    ax.plot(angles, stats, 'o-', linewidth=2, label = "Features 1", color= 'gray')
    ax.fill(angles, stats, alpha=0.25, facecolor='blue')
    ax.set_thetagrids(angles[0:7] * 180/np.pi, labels , fontsize = 13)

    ax.set_rlabel_position(250)
    plt.yticks([0.25 , 0.5 , 0.75 , 1], ["0.25",'0.5', "0.75", "1"], color="grey", size=13)
    plt.ylim(0,1)

    ax.plot(angles, stats2, 'o-', linewidth=2, label = "Features 2", color = 'm')
    ax.fill(angles, stats2, alpha=0.25, facecolor='m' )
    ax.set_title('Mean Values of the audio features')
    ax.grid(True)

    plt.legend(loc='best', bbox_to_anchor=(0.095, 0.095))

# %%
track_audio_specs2  = sp.audio_features('3j3XiRDNkaUfINMB99hphS')
df2 = pd.DataFrame(track_audio_specs2, index=[0])
df_audio_specs2 = df2.loc[:,['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence']]

# %%
feature_plot2(df_audio_specs,df_audio_specs2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
if len(tracks['tracks']['items']) > 0:
  for item in tracks['tracks']['items']:   
    print(item['id'])
# Out:
# 6I3mqTwhRpn34SLVafSH7G
# 7vgTNTaEz3CsBZ1N4YQalM
# 569uHYIB0X324FZOBEhvit
# 5dPz35akJjPqb17yeqNwqH
# 135Lf4Q0CzlMNfOxbEUsLH
# 1TQXIltqoZ5XXyfCbAeSQQ
# 1MhXdlCQPnO56T57MfmaRm
# 30uCmqegKQnH5AbOE51gPD
# 1Y2583xYzwiEXDetAB7H1Q
# 4B1rpPmQXwj78wk6aIGwwU
# 1yKAqZoi8xWGLCf5vajroL
# 7Kbw2fTMOU43MrqXdGzroh
# 5u6vkDnOyaf8LsteDAj2ub
# 2FGOg7uYBfnspkPOISXTFY
# 0R3TWpoxAhT3HDXM7tpRzS
# 3m0y8qLoznUYi73SUBP8GI
# 7CHMY5TN1e8oqDnRwwJR61
# 3vZUC1m6QVm7urnN6lcF64
# 5LAVhynnTmj9VJjW8xGZdP
# 4AiFSXnVm0Bqecjdn3Brr8

# %%
lst = []
if len(tracks['tracks']['items']) > 0:
  for item in tracks['tracks']['items']:   
    track_audio_specs  = sp.audio_features(item['id'])
    lst.append(track_audio_specs)

# %% [markdown]
# ## **GENERATING TOKEN FOR RECOMMENDATION**

# %%
import requests
import base64

def get_token(clientId,clientSecret):
    url = "https://accounts.spotify.com/api/token"
    headers = {}
    data = {}
    message = f"{clientId}:{clientSecret}"
    messageBytes = message.encode('ascii')
    base64Bytes = base64.b64encode(messageBytes)
    base64Message = base64Bytes.decode('ascii')
    headers['Authorization'] = "Basic " + base64Message
    data['grant_type'] = "client_credentials"
    r = requests.post(url, headers=headers, data=data)
    token = r.json()['access_token']
    return token

# %%
token = get_token(SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET)

# %%
token
# Out:
# 'BQD8WskvkkEPcnmMHAQnolK_2vS5wD6xmKpK7OipI-aJjnLceSzmkhV10fYun_VcxL7G8HgdaiW26f27yucUk8I7doh1150TMspc9QBo8m--gJTtbxA'

# %% [markdown]
# ## **GETTING RECOMMENDATION BASED ON SONG**

# %%
def get_track_recommendations(seed_tracks,token):
    limit = 100
    recUrl = f"https://api.spotify.com/v1/recommendations?limit={limit}&seed_tracks={seed_tracks}"

    headers = {
        "Authorization": "Bearer " + token
    }

    res = requests.get(url=recUrl, headers=headers)
    return res.json()

# %%
track_id = '6I3mqTwhRpn34SLVafSH7G'
json_response = get_track_recommendations(track_id,token)

# %%
json_response

# %%
recc_track_result = []
for i, item in enumerate(json_response['tracks']):
    track = item['album']
    track_id = item['id']
    track_name = item['name']
    popularity = item['popularity']
    explicit = item['explicit']
    duration = ((item['duration_ms']/1000)/60)
    preview_url = item['preview_url']
    recc_track_result.append((i, track['artists'][0]['name'], track['name'], track_id, track_name, track['release_date'], popularity, explicit, duration, preview_url))

# %%
recc_track_result

# %%
import pandas as pd
recc_track_result_df = pd.DataFrame(recc_track_result, index=None, columns=('Item', 'Artist', 'Album Name', 'Id', 'Song Name', 'Release Date', 'Popularity','Explicit','Duration_mins','Preview_url'))

audio_features_df = pd.DataFrame()
for id in recc_track_result_df['Id'].iteritems():
    track_id = id[1]
    audio_features = sp.audio_features(track_id)
    local_features = pd.DataFrame(audio_features, index=[0])
    audio_features_df = audio_features_df.append(local_features)

# %%
audio_features_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.592   0.342    0    -8.930     1       0.0339      0.193000
# 0          0.721   0.745    7    -3.508     0       0.0366      0.151000
# 0          0.583   0.670    8    -7.289     1       0.0646      0.037400
# 0          0.602   0.626    2    -5.323     0       0.0396      0.012900
# 0          0.386   0.426    3    -6.642     1       0.0363      0.807000
# ..           ...     ...  ...       ...   ...          ...           ...
# 0          0.599   0.866   10    -2.808     1       0.0629      0.359000
# 0          0.881   0.592    2    -4.898     1       0.0324      0.619000
# 0          0.673   0.729    0    -5.664     1       0.0290      0.000983
# 0          0.717   0.734    5    -5.712     1       0.0426      0.280000
# 0          0.606   0.513    9    -8.756     1       0.0524      0.102000
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.002450    0.1100    0.155  130.953  audio_features
# 0           0.000001    0.3720    0.699   90.988  audio_features
# 0           0.000100    0.1260    0.498  140.061  audio_features
# 0           0.000009    0.1440    0.619  160.118  audio_features
# 0           0.000000    0.1400    0.261  180.104  audio_features
# ..               ...       ...      ...      ...             ...
# 0           0.000000    0.1070    0.391  147.934  audio_features
# 0           0.000013    0.0901    0.719  101.058  audio_features
# 0           0.000107    0.2260    0.482  112.535  audio_features
# 0           0.000101    0.1470    0.894   91.014  audio_features
# 0           0.000000    0.1560    0.177   79.900  audio_features
#
#                         id                                   uri  \
# 0   4cGqn0E8JCSY9gQllQj4Mf  spotify:track:4cGqn0E8JCSY9gQllQj4Mf
# 0   6FuGJB290AQMAHTfjOYVaK  spotify:track:6FuGJB290AQMAHTfjOYVaK
# 0   1Ov37jtRQ2YNAe8HzfczkL  spotify:track:1Ov37jtRQ2YNAe8HzfczkL
# 0   7l9IqDtVWJurTvkQHq1BGh  spotify:track:7l9IqDtVWJurTvkQHq1BGh
# 0   5ajjAnNRh8bxFvaVHzpPjh  spotify:track:5ajjAnNRh8bxFvaVHzpPjh
# ..                     ...                                   ...
# 0   4sxssJY6nbqDHnsgZPkRZW  spotify:track:4sxssJY6nbqDHnsgZPkRZW
# 0   5Odq8ohlgIbQKMZivbWkEo  spotify:track:5Odq8ohlgIbQKMZivbWkEo
# 0   2wJ1eOCIBwoQiN7xQtrTAY  spotify:track:2wJ1eOCIBwoQiN7xQtrTAY
# 0   7dTd00X8Mc5iErfQQyBA6B  spotify:track:7dTd00X8Mc5iErfQQyBA6B
# 0   1TlTzdsEpgfsmbuNfYmWfG  spotify:track:1TlTzdsEpgfsmbuNfYmWfG
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4cGqn0E8JCSY...
# 0   https://api.spotify.com/v1/tracks/6FuGJB290AQM...
# 0   https://api.spotify.com/v1/tracks/1Ov37jtRQ2YN...
# 0   https://api.spotify.com/v1/tracks/7l9IqDtVWJur...
# 0   https://api.spotify.com/v1/tracks/5ajjAnNRh8bx...
# ..                                                ...
# 0   https://api.spotify.com/v1/tracks/4sxssJY6nbqD...
# 0   https://api.spotify.com/v1/tracks/5Odq8ohlgIbQ...
# 0   https://api.spotify.com/v1/tracks/2wJ1eOCIBwoQ...
# 0   https://api.spotify.com/v1/tracks/7dTd00X8Mc5i...
# 0   https://api.spotify.com/v1/tracks/1TlTzdsEpgfs...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4cGq...       241595
# 0   https://api.spotify.com/v1/audio-analysis/6FuG...       192745
# 0   https://api.spotify.com/v1/audio-analysis/1Ov3...       220433
# 0   https://api.spotify.com/v1/audio-analysis/7l9I...       207120
# 0   https://api.spotify.com/v1/audio-analysis/5ajj...       203385
# ..                                                ...          ...
# 0   https://api.spotify.com/v1/audio-analysis/4sxs...       219453
# 0   https://api.spotify.com/v1/audio-analysis/5Odq...       154487
# 0   https://api.spotify.com/v1/audio-analysis/2wJ1...       233588
# 0   https://api.spotify.com/v1/audio-analysis/7dTd...       171360
# 0   https://api.spotify.com/v1/audio-analysis/1TlT...       192257
#
#     time_signature
# 0                4
# 0                4
# 0                4
# 0                4
# 0                3
# ..             ...
# 0                4
# 0                4
# 0                4
# 0                4
# 0                4
#
# [100 rows x 18 columns]

# %%
our_final_df = recc_track_result_df.merge(audio_features_df, left_on="Id", right_on="id")
our_final_df
# Out:
#     Item            Artist                                         Album Name  \
# 0      0          Coldplay                               Music Of The Spheres
# 1      1          24kGoldn  Mood (Remix) feat. Justin Bieber, J Balvin & i...
# 2      2      Taylor Swift                  Wildest Dreams (Taylor's Version)
# 3      3        Tate McRae                        i used to think i could fly
# 4      4      Madison Beer                                           Reckless
# ..   ...               ...                                                ...
# 95    95           Ruth B.                                         Safe Haven
# 96    96      Charlie Puth                                            CHARLIE
# 97    97              Ruel                                GROWING UP IS _____
# 98    98  The Chainsmokers                                     So Far So Good
# 99    99            Giveon                                       Give Or Take
#
#                         Id                                          Song Name  \
# 0   4cGqn0E8JCSY9gQllQj4Mf                                    Let Somebody Go
# 1   6FuGJB290AQMAHTfjOYVaK  Mood (Remix) feat. Justin Bieber, J Balvin & i...
# 2   1Ov37jtRQ2YNAe8HzfczkL                  Wildest Dreams (Taylor's Version)
# 3   7l9IqDtVWJurTvkQHq1BGh                               she's all i wanna be
# 4   5ajjAnNRh8bxFvaVHzpPjh                                           Reckless
# ..                     ...                                                ...
# 95  4sxssJY6nbqDHnsgZPkRZW                  Superficial Love - Single Version
# 96  5Odq8ohlgIbQKMZivbWkEo            Left and Right (Feat. Jung Kook of BTS)
# 97  2wJ1eOCIBwoQiN7xQtrTAY                                GROWING UP IS _____
# 98  7dTd00X8Mc5iErfQQyBA6B                                            Riptide
# 99  1TlTzdsEpgfsmbuNfYmWfG                                        For Tonight
#
#    Release Date  Popularity  Explicit  Duration_mins  \
# 0    2021-10-15          78     False       4.026583
# 1    2020-11-06          70      True       3.212417
# 2    2021-09-17          82     False       3.673883
# 3    2022-05-27          75     False       3.452000
# 4    2021-06-04          79     False       3.389733
# ..          ...         ...       ...            ...
# 95   2017-05-05          60     False       3.657550
# 96   2022-10-06          79     False       2.574767
# 97   2021-12-08          66     False       3.893117
# 98   2022-06-08          64     False       2.855983
# 99   2022-06-24          71     False       3.204283
#
#                                           Preview_url  ...  liveness  valence  \
# 0   https://p.scdn.co/mp3-preview/7f7024b0a66ce53e...  ...    0.1100    0.155
# 1   https://p.scdn.co/mp3-preview/0e4989080f7d1792...  ...    0.3720    0.699
# 2                                                None  ...    0.1260    0.498
# 3   https://p.scdn.co/mp3-preview/39af9db8e9500261...  ...    0.1440    0.619
# 4   https://p.scdn.co/mp3-preview/05db5423d117de44...  ...    0.1400    0.261
# ..                                                ...  ...       ...      ...
# 95  https://p.scdn.co/mp3-preview/44201ea5af1c5201...  ...    0.1070    0.391
# 96  https://p.scdn.co/mp3-preview/7b872d741e9af03f...  ...    0.0901    0.719
# 97  https://p.scdn.co/mp3-preview/5d9c6f93e5f082db...  ...    0.2260    0.482
# 98  https://p.scdn.co/mp3-preview/1d354a934fdc5c34...  ...    0.1470    0.894
# 99  https://p.scdn.co/mp3-preview/871b7c608753ca0c...  ...    0.1560    0.177
#
#       tempo            type                      id  \
# 0   130.953  audio_features  4cGqn0E8JCSY9gQllQj4Mf
# 1    90.988  audio_features  6FuGJB290AQMAHTfjOYVaK
# 2   140.061  audio_features  1Ov37jtRQ2YNAe8HzfczkL
# 3   160.118  audio_features  7l9IqDtVWJurTvkQHq1BGh
# 4   180.104  audio_features  5ajjAnNRh8bxFvaVHzpPjh
# ..      ...             ...                     ...
# 95  147.934  audio_features  4sxssJY6nbqDHnsgZPkRZW
# 96  101.058  audio_features  5Odq8ohlgIbQKMZivbWkEo
# 97  112.535  audio_features  2wJ1eOCIBwoQiN7xQtrTAY
# 98   91.014  audio_features  7dTd00X8Mc5iErfQQyBA6B
# 99   79.900  audio_features  1TlTzdsEpgfsmbuNfYmWfG
#
#                                      uri  \
# 0   spotify:track:4cGqn0E8JCSY9gQllQj4Mf
# 1   spotify:track:6FuGJB290AQMAHTfjOYVaK
# 2   spotify:track:1Ov37jtRQ2YNAe8HzfczkL
# 3   spotify:track:7l9IqDtVWJurTvkQHq1BGh
# 4   spotify:track:5ajjAnNRh8bxFvaVHzpPjh
# ..                                   ...
# 95  spotify:track:4sxssJY6nbqDHnsgZPkRZW
# 96  spotify:track:5Odq8ohlgIbQKMZivbWkEo
# 97  spotify:track:2wJ1eOCIBwoQiN7xQtrTAY
# 98  spotify:track:7dTd00X8Mc5iErfQQyBA6B
# 99  spotify:track:1TlTzdsEpgfsmbuNfYmWfG
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4cGqn0E8JCSY...
# 1   https://api.spotify.com/v1/tracks/6FuGJB290AQM...
# 2   https://api.spotify.com/v1/tracks/1Ov37jtRQ2YN...
# 3   https://api.spotify.com/v1/tracks/7l9IqDtVWJur...
# 4   https://api.spotify.com/v1/tracks/5ajjAnNRh8bx...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/4sxssJY6nbqD...
# 96  https://api.spotify.com/v1/tracks/5Odq8ohlgIbQ...
# 97  https://api.spotify.com/v1/tracks/2wJ1eOCIBwoQ...
# 98  https://api.spotify.com/v1/tracks/7dTd00X8Mc5i...
# 99  https://api.spotify.com/v1/tracks/1TlTzdsEpgfs...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4cGq...       241595
# 1   https://api.spotify.com/v1/audio-analysis/6FuG...       192745
# 2   https://api.spotify.com/v1/audio-analysis/1Ov3...       220433
# 3   https://api.spotify.com/v1/audio-analysis/7l9I...       207120
# 4   https://api.spotify.com/v1/audio-analysis/5ajj...       203385
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/4sxs...       219453
# 96  https://api.spotify.com/v1/audio-analysis/5Odq...       154487
# 97  https://api.spotify.com/v1/audio-analysis/2wJ1...       233588
# 98  https://api.spotify.com/v1/audio-analysis/7dTd...       171360
# 99  https://api.spotify.com/v1/audio-analysis/1TlT...       192257
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                3
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 28 columns]

# %%
our_final_df.Popularity.value_counts(bins=5)
# Out:
# (57.8, 68.2]      34
# (68.2, 78.6]      25
# (47.4, 57.8]      17
# (78.6, 89.0]      15
# (36.947, 47.4]     9
# Name: Popularity, dtype: int64

# %%
our_final_df.dtypes
# Out:
# Item                  int64
# Artist               object
# Album Name           object
# Id                   object
# Song Name            object
# Release Date         object
# Popularity            int64
# Explicit               bool
# Duration_mins       float64
# Preview_url          object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# dtype: object

# %%
our_final_df.columns
# Out:
# Index(['Item', 'Artist', 'Album Name', 'Id', 'Song Name', 'Release Date',
#        'Popularity', 'Explicit', 'Duration_mins', 'Preview_url',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
import seaborn as sns

# %%
corr = our_final_df[['Release Date', 'Popularity', 'Explicit', 'Duration_mins', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']].corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot = True, cmap="icefire_r") # copper_r, icefire,icefire_r

# %%
our_final_df
# Out:
#     Item            Artist                                         Album Name  \
# 0      0          Coldplay                               Music Of The Spheres
# 1      1          24kGoldn  Mood (Remix) feat. Justin Bieber, J Balvin & i...
# 2      2      Taylor Swift                  Wildest Dreams (Taylor's Version)
# 3      3        Tate McRae                        i used to think i could fly
# 4      4      Madison Beer                                           Reckless
# ..   ...               ...                                                ...
# 95    95           Ruth B.                                         Safe Haven
# 96    96      Charlie Puth                                            CHARLIE
# 97    97              Ruel                                GROWING UP IS _____
# 98    98  The Chainsmokers                                     So Far So Good
# 99    99            Giveon                                       Give Or Take
#
#                         Id                                          Song Name  \
# 0   4cGqn0E8JCSY9gQllQj4Mf                                    Let Somebody Go
# 1   6FuGJB290AQMAHTfjOYVaK  Mood (Remix) feat. Justin Bieber, J Balvin & i...
# 2   1Ov37jtRQ2YNAe8HzfczkL                  Wildest Dreams (Taylor's Version)
# 3   7l9IqDtVWJurTvkQHq1BGh                               she's all i wanna be
# 4   5ajjAnNRh8bxFvaVHzpPjh                                           Reckless
# ..                     ...                                                ...
# 95  4sxssJY6nbqDHnsgZPkRZW                  Superficial Love - Single Version
# 96  5Odq8ohlgIbQKMZivbWkEo            Left and Right (Feat. Jung Kook of BTS)
# 97  2wJ1eOCIBwoQiN7xQtrTAY                                GROWING UP IS _____
# 98  7dTd00X8Mc5iErfQQyBA6B                                            Riptide
# 99  1TlTzdsEpgfsmbuNfYmWfG                                        For Tonight
#
#    Release Date  Popularity  Explicit  Duration_mins  \
# 0    2021-10-15          78     False       4.026583
# 1    2020-11-06          70      True       3.212417
# 2    2021-09-17          82     False       3.673883
# 3    2022-05-27          75     False       3.452000
# 4    2021-06-04          79     False       3.389733
# ..          ...         ...       ...            ...
# 95   2017-05-05          60     False       3.657550
# 96   2022-10-06          79     False       2.574767
# 97   2021-12-08          66     False       3.893117
# 98   2022-06-08          64     False       2.855983
# 99   2022-06-24          71     False       3.204283
#
#                                           Preview_url  ...  liveness  valence  \
# 0   https://p.scdn.co/mp3-preview/7f7024b0a66ce53e...  ...    0.1100    0.155
# 1   https://p.scdn.co/mp3-preview/0e4989080f7d1792...  ...    0.3720    0.699
# 2                                                None  ...    0.1260    0.498
# 3   https://p.scdn.co/mp3-preview/39af9db8e9500261...  ...    0.1440    0.619
# 4   https://p.scdn.co/mp3-preview/05db5423d117de44...  ...    0.1400    0.261
# ..                                                ...  ...       ...      ...
# 95  https://p.scdn.co/mp3-preview/44201ea5af1c5201...  ...    0.1070    0.391
# 96  https://p.scdn.co/mp3-preview/7b872d741e9af03f...  ...    0.0901    0.719
# 97  https://p.scdn.co/mp3-preview/5d9c6f93e5f082db...  ...    0.2260    0.482
# 98  https://p.scdn.co/mp3-preview/1d354a934fdc5c34...  ...    0.1470    0.894
# 99  https://p.scdn.co/mp3-preview/871b7c608753ca0c...  ...    0.1560    0.177
#
#       tempo            type                      id  \
# 0   130.953  audio_features  4cGqn0E8JCSY9gQllQj4Mf
# 1    90.988  audio_features  6FuGJB290AQMAHTfjOYVaK
# 2   140.061  audio_features  1Ov37jtRQ2YNAe8HzfczkL
# 3   160.118  audio_features  7l9IqDtVWJurTvkQHq1BGh
# 4   180.104  audio_features  5ajjAnNRh8bxFvaVHzpPjh
# ..      ...             ...                     ...
# 95  147.934  audio_features  4sxssJY6nbqDHnsgZPkRZW
# 96  101.058  audio_features  5Odq8ohlgIbQKMZivbWkEo
# 97  112.535  audio_features  2wJ1eOCIBwoQiN7xQtrTAY
# 98   91.014  audio_features  7dTd00X8Mc5iErfQQyBA6B
# 99   79.900  audio_features  1TlTzdsEpgfsmbuNfYmWfG
#
#                                      uri  \
# 0   spotify:track:4cGqn0E8JCSY9gQllQj4Mf
# 1   spotify:track:6FuGJB290AQMAHTfjOYVaK
# 2   spotify:track:1Ov37jtRQ2YNAe8HzfczkL
# 3   spotify:track:7l9IqDtVWJurTvkQHq1BGh
# 4   spotify:track:5ajjAnNRh8bxFvaVHzpPjh
# ..                                   ...
# 95  spotify:track:4sxssJY6nbqDHnsgZPkRZW
# 96  spotify:track:5Odq8ohlgIbQKMZivbWkEo
# 97  spotify:track:2wJ1eOCIBwoQiN7xQtrTAY
# 98  spotify:track:7dTd00X8Mc5iErfQQyBA6B
# 99  spotify:track:1TlTzdsEpgfsmbuNfYmWfG
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4cGqn0E8JCSY...
# 1   https://api.spotify.com/v1/tracks/6FuGJB290AQM...
# 2   https://api.spotify.com/v1/tracks/1Ov37jtRQ2YN...
# 3   https://api.spotify.com/v1/tracks/7l9IqDtVWJur...
# 4   https://api.spotify.com/v1/tracks/5ajjAnNRh8bx...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/4sxssJY6nbqD...
# 96  https://api.spotify.com/v1/tracks/5Odq8ohlgIbQ...
# 97  https://api.spotify.com/v1/tracks/2wJ1eOCIBwoQ...
# 98  https://api.spotify.com/v1/tracks/7dTd00X8Mc5i...
# 99  https://api.spotify.com/v1/tracks/1TlTzdsEpgfs...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4cGq...       241595
# 1   https://api.spotify.com/v1/audio-analysis/6FuG...       192745
# 2   https://api.spotify.com/v1/audio-analysis/1Ov3...       220433
# 3   https://api.spotify.com/v1/audio-analysis/7l9I...       207120
# 4   https://api.spotify.com/v1/audio-analysis/5ajj...       203385
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/4sxs...       219453
# 96  https://api.spotify.com/v1/audio-analysis/5Odq...       154487
# 97  https://api.spotify.com/v1/audio-analysis/2wJ1...       233588
# 98  https://api.spotify.com/v1/audio-analysis/7dTd...       171360
# 99  https://api.spotify.com/v1/audio-analysis/1TlT...       192257
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                3
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 28 columns]

# %%
sns.scatterplot(x = "danceability", 
                y = "Popularity", 
                data = our_final_df, size='Popularity', hue='Popularity', sizes=(10,200), legend=False)

# %%
sns.scatterplot(x = "Duration_mins", 
                y = "Popularity", 
                data = our_final_df, size='Popularity', hue='Popularity', sizes=(10,200), legend=False)

# %%
sns.scatterplot(x = "loudness", 
                y = "Popularity", 
                data = our_final_df, size='Popularity', hue='Popularity', sizes=(10,200), legend=False)

# %%
sns.scatterplot(x = "tempo",
                y = "Popularity", 
                data = our_final_df, size='Popularity', hue='Popularity', sizes=(10,200), legend=False)

# %%
sns.histplot(
    data=our_final_df, x="Duration_mins", y="Popularity",
    bins=25, discrete=(False, False), log_scale=(False, False), thresh=None,
)

# %%
sns.histplot(data=our_final_df, x="loudness", y="energy", bins=15, discrete=(False, False), log_scale=(False, False), thresh=None,color='#03051A')

# %%
sns.histplot(
    data=our_final_df, x="valence", y="danceability",
    bins=15, discrete=(False, False), log_scale=(False, False), thresh=None,
)

# %%
sns.histplot(
    data=our_final_df, x="acousticness", y="energy",
    bins=15, discrete=(False, False), log_scale=(False, False), thresh=None,
)

# %%
sns.histplot(
    data=our_final_df, x="acousticness", y="loudness",
    bins=15, discrete=(False, False), log_scale=(False, False), thresh=None,
)

# %%
import altair as alt

# %%
sorted_df = our_final_df.sort_values(by=['Popularity'],ascending=False)

# %%
alt.Chart(sorted_df).mark_circle().encode(
alt.X('Popularity', scale=alt.Scale(zero=False)), y='tempo', color=alt.Color('Popularity', scale=alt.Scale(zero=False)), 
size=alt.value(200), tooltip=['Popularity','tempo', 'Song Name', 'Album Name'])
# Out:
# alt.Chart(...)

# %%
alt.Chart(sorted_df).mark_circle().encode(
alt.X('acousticness', scale=alt.Scale(zero=False)), y='loudness', color=alt.Color('Popularity', scale=alt.Scale(zero=False)), 
size=alt.value(200), tooltip=['Popularity','tempo', 'Song Name', 'Album Name'])
# Out:
# alt.Chart(...)

# %%
alt.Chart(sorted_df).mark_circle().encode(
alt.X('danceability', scale=alt.Scale(zero=False)), y='valence', color=alt.Color('Popularity', scale=alt.Scale(zero=False)), 
size=alt.value(200), tooltip=['Popularity','tempo', 'Song Name', 'Album Name'])
# Out:
# alt.Chart(...)

# %%
plt.figure(figsize = (125, 45))
sns.set(font_scale = 4)
plt.subplot(331)
sns.countplot(df['Gender'],hue=df['Loan_Status'])
plt.subplot(332)
sns.countplot(df['Married'],hue=df['Loan_Status'])
plt.subplot(334)
sns.countplot(df['Dependents'],hue=df['Loan_Status'])
plt.subplot(335)

# %%
sns.histplot(data=our_final_df, x="loudness",color='#03051A', hue="Explicit",kde = True)

# %%
sns.histplot(data=our_final_df, x="danceability", hue="Explicit",kde = True)

# %%
sns.histplot(data=our_final_df, x="acousticness", hue="Explicit",kde = True)

# %%
sns.histplot(data=our_final_df, x="energy", hue="Explicit",kde = True)

# %%
sns.lmplot(x='Popularity',y='Duration_mins',data=our_final_df,hue='Explicit',palette='Set1', height=8, aspect=1.5, size=5)

# %%
sns.lmplot(x='Popularity',y='Duration_mins',data=our_final_df,col='Explicit',palette='Set1', height=8, aspect=1.5, size=5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.lineplot(data=our_final_df,x='loudness',y='Popularity',color='#03051A')

# %%
import seaborn as sns
sns.set_theme(style="ticks")
g = sns.jointplot(
    data=our_final_df,
    x="loudness", y="Popularity", hue="Explicit",
    kind="kde", color='#03051A'
)

# %%
sns.jointplot(data=our_final_df, x="danceability", y="Popularity",kind="reg", color='#03051A')

# %%
import seaborn as sns
sns.set_theme(style="ticks")
g = sns.jointplot(
    data=our_final_df,
    x="liveness", y="Popularity",
    kind="reg", color='#03051A'
)

# %%
sns.jointplot(data=our_final_df, x="danceability", y="Popularity",kind="reg", color='#03051A')

# %%
import seaborn as sns
sns.set_theme(style="ticks")
g = sns.jointplot(
    data=our_final_df,
    x="tempo", y="Popularity",
    kind="reg", color='#03051A'
)

# %%
import seaborn as sns
sns.set_theme(style="ticks")
g = sns.jointplot(data=our_final_df, x="liveness", y="valence", kind="hex", color='#826778')

# %%
import seaborn as sns
sns.set_theme(style="ticks")
g = sns.jointplot(
    data=our_final_df,
    x="loudness", y="Popularity",
    kind="scatter", color='#03051A'
)

# %%
g = sns.jointplot(
    data=our_final_df,
    x="tempo", y="acousticness",
    kind="kde", color='#03051A',cmap='rocket',fill=True,thresh=0
)

# %%
our_final_df.dtypes
# Out:
# Item                  int64
# Artist               object
# Album Name           object
# Id                   object
# Song Name            object
# Release Date         object
# Popularity            int64
# Explicit               bool
# Duration_mins       float64
# Preview_url          object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# dtype: object

# %%
f1 = plt.figure(figsize=(15,13))  
plt.subplot(331)
g = sns.JointGrid(data=our_final_df, x="tempo", y="acousticness", space=0)
g.plot_joint(sns.kdeplot,fill=True,cmap="rocket",thresh=-0.1)
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)
plt.subplot(332)
g = sns.JointGrid(data=our_final_df, x="valence", y="energy", space=0)
g.plot_joint(sns.kdeplot,fill=True,cmap="rocket",thresh=-0.1)
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)
plt.subplot(333)
g = sns.JointGrid(data=our_final_df, x="acousticness", y="valence", space=0)
g.plot_joint(sns.kdeplot,fill=True,cmap="rocket",thresh=-0.1)
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)

# %%
sns.set_theme(style="white")
g = sns.JointGrid(data=our_final_df, x="tempo", y="acousticness", space=0)
g.plot_joint(sns.kdeplot,fill=True,cmap="rocket",thresh=-0.1)
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)

# %%
with sns.axes_style('white'):
    sns.jointplot(x="Popularity", y="tempo", data=our_final_df, kind='hex',cmap="mako",color="#03051A")

# %%
with sns.axes_style('white'):
    sns.jointplot(x="loudness", y="energy", data=our_final_df, kind='hex',cmap="rocket",color="#03051A")

# %%
with sns.axes_style('white'):
    sns.jointplot(x="Popularity", y="tempo", data=our_final_df, kind='scatter',cmap="mako",color="#03051A")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

sns.boxenplot(x="Explicit", y="danceability",
              color="b",
              scale="linear", data=our_final_df)

# %%
ordered = our_final_df.Explicit.value_counts().index
g = sns.FacetGrid(our_final_df, row="Explicit", row_order=ordered,
                  height=1.7, aspect=4,)
g.map(sns.kdeplot, "Popularity",fill=True,color="#03051A")

# %%
def sinplot(n=10, flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, n + 1):
        plt.plot(x, np.sin(x + i * .5) * (n + 2 - i) * flip)

# %%
sinplot()

# %%
sns.scatterplot(x = "Explicit", 
                y = "Popularity", 
                data = our_final_df, size='Popularity', hue='Popularity', sizes=(10,200), legend=False)

# %%
sns.catplot(data=our_final_df, x="Explicit", y="key", kind="violin", color=".9", inner=None)
sns.swarmplot(data=our_final_df, x="Explicit", y="key", size=3)

# %%
sns.catplot(data=our_final_df, x="Explicit", y="key", hue="Explicit", kind="boxen")

# %%
sns.histplot(data=our_final_df, x="loudness", hue="Explicit")

# %%
sns.histplot(data=our_final_df, x="danceability", hue="Explicit")

# %%
sns.histplot(
    data=our_final_df, x="Duration_mins", y="Popularity",
    bins=25, discrete=(False, False), log_scale=(False, False), thresh=None,
)

# %%
sns.histplot(
    data=our_final_df, x="loudness", y="energy",
    bins=25, discrete=(False, False), log_scale=(False, False), thresh=None,
)

# %%
sns.violinplot(x = "Explicit", y = "key", 
               data = our_final_df)

# %%
find_prev_url = sp.search(q='href:' + '0bUTovzE275S4sfnJU1DMw')
find_prev_url['tracks']['href']

# %%
sp.audio_features('0bUTovzE275S4sfnJU1DMw')
# Out:
# [{'danceability': 0.812,
#   'energy': 0.615,
#   'key': 8,
#   'loudness': -9.646,
#   'mode': 1,
#   'speechiness': 0.413,
#   'acousticness': 0.186,
#   'instrumentalness': 0,
#   'liveness': 0.141,
#   'valence': 0.569,
#   'tempo': 141.907,
#   'type': 'audio_features',
#   'id': '0bUTovzE275S4sfnJU1DMw',
#   'uri': 'spotify:track:0bUTovzE275S4sfnJU1DMw',
#   'track_href': 'https://api.spotify.com/v1/tracks/0bUTovzE275S4sfnJU1DMw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0bUTovzE275S4sfnJU1DMw',
#   'duration_ms': 122973,
#   'time_signature': 4}]

# %%
tracks_list = tracks['tracks']['items'] 
tracks = sp.search(q='spotify:track:0bUTovzE275S4sfnJU1DMw',type='track', limit=25)

# %%
tracks = sp.search(q='track:' + '0bUTovzE275S4sfnJU1DMw', type='track') 
tracks
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3A0bUTovzE275S4sfnJU1DMw&type=track&offset=0&limit=10',
#   'items': [],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0}}

# %%
tracks['tracks']['items'][0]['preview_url']
# Out:
# 'https://p.scdn.co/mp3-preview/38fc12a77916a43bea470d18bef6a3542f8e9fae?cid=a9c08768bf6f4d5083cdafbbf17c2277'

# %%
def get_track_recommendations(seed_tracks,token):
    limit = 100
    recUrl = f"https://api.spotify.com/v1/recommendations?limit={limit}&seed_tracks={seed_tracks}"

    headers = {
        "Authorization": "Bearer " + token
    }

    res = requests.get(url=recUrl, headers=headers)
    return res.json()

# %%
track_id = '3j3XiRDNkaUfINMB99hphS'
json_response = get_track_recommendations(track_id,token)

# %%
lst = []
for reccomended_songs in json_response['tracks']:
  print(f"{reccomended_songs['name']} || Author: {reccomended_songs['artists'][0]['name']}")
  lst.append(reccomended_songs)
# Out:
# Just A Lil Bit || Author: 50 Cent
# Hero || Author: Skillet
# My Time || Author: Fabolous
# What If I Was White || Author: Sticky Fingaz
# Scarface of Facebook || Author: Mads Veslelia
# Do Or Die || Author: A-Connection
# Majesty (with Labrinth & feat. Eminem) || Author: Nicki Minaj
# No Church In The Wild || Author: JAY-Z
# Scary Movies || Author: Bad Meets Evil
# 99 Problems BC - Rock Mix || Author: Body Count
# From tha D Remix (feat. Eminem & Kid Rock) || Author: Trick Trick
# Lose Yourself - From "8 Mile" Soundtrack || Author: Eminem
# Spinnin || Author: Connor Price
# We Ain't || Author: The Game
# King Of The Jungle || Author: Vin Jay
# Welcome 2 Hell || Author: Bad Meets Evil
# Flexicution || Author: Logic
# FUXK (feat. Ski Mask the Slump God) || Author: XXXTENTACION
# Rap Nemesis || Author: Chris Webby
# Step Back! || Author: 1nonly
# Don't Push Me || Author: 50 Cent
# Psychopath Killer || Author: Slaughterhouse
# Welcome to Planet X (We're Coming for You) [with Eminem & The Observer] || Author: KXNG Crooked
# Ready To Go || Author: Limp Bizkit
# Outcast || Author: Cognito
# The Hills - Remix || Author: The Weeknd
# Numb / Encore || Author: JAY-Z
# Take Your Crown || Author: BLANK
# Superman || Author: Eminem
# Omen (Dubstep Remix) || Author: Remedy
# Favorite Rapper || Author: Ballin' Wallin
# Throw It Up || Author: Yelawolf
# Fuck Wit Us || Author: Salam Wreck
# We Don't Give A Fuck || Author: Tony Yayo
# Slap Happy || Author: The Jokerr
# Congratulations || Author: Post Malone
# In the Zone || Author: P.L.
# Above The Law || Author: Bad Meets Evil
# Lady || Author: Obie Trice
# Can't Hold Us (feat. Ray Dalton) || Author: Macklemore & Ryan Lewis
# Nuttin' to Do || Author: Royce Da 5'9"
# Slim Shady || Author: Sinner
# Wolves (feat. Post Malone) || Author: Big Sean
# Numb || Author: Rihanna
# Serenade My Life || Author: Ca$his
# MetaFreeverse || Author: Chris Webby
# P.I.M.P. || Author: 50 Cent
# One Day At A Time - Em's Version || Author: 2Pac
# Know What I Am || Author: DMX
# Rap God || Author: Eminem
# Crank That (Soulja Boy) [Travis Barker Remix] || Author: Soulja Boy
# Black Skinhead || Author: Kanye West
# Renegade || Author: JAY-Z
# asBESTos || Author: Necro
# Go Hard, Go Home (feat. Giz, Swellz & Choppa) || Author: Roy Jones Jr.
# Cleanin' Out My Closet || Author: Eminem
# Black and Yellow || Author: Wiz Khalifa
# Pass the Glock (feat. Big Pun, Prospect, Fat Joe, Triple Seis, Cuban Link, & Armageaddon) || Author: Terror Squad
# Living Proof || Author: Bad Meets Evil
# Wild for the Night (feat. Skrillex & Birdy Nam Nam) || Author: A$AP Rocky
# POWER || Author: Kanye West
# I Don't Dance || Author: DMX
# Bad Ass (feat. Meek Mill & Wale) || Author: Kid Ink
# RIP Roach || Author: XXXTENTACION
# Talk Dirty (feat. 2 Chainz) || Author: Jason Derulo
# Buffalo Bill || Author: Eminem
# X Gon' Give It To Ya - Int'l Bonus track || Author: DMX
# Stronger || Author: Kanye West
# In the End || Author: Linkin Park
# Reasons || Author: Diabolic
# Scary Movie (Sonorous Star Remix) [feat. Eminem & Royce Da 5'9''] || Author: Bad Meets Evil
# Like Toy Soldiers || Author: Eminem
# Where The Hood At || Author: DMX
# Ye Not Crazy || Author: Joyner Lucas
# (Rap) Superstar (feat. Eminem & Noreaga) || Author: Cypress Hill
# Ballin || Author: Logic
# I Mean It (feat. Remo) || Author: G-Eazy
# Take From Me || Author: Bad Meets Evil
# Murder In My Mind || Author: Kordhell
# Menace || Author: Sione
# White America || Author: Eminem
# Me, Myself & I || Author: G-Eazy
# Started From the Bottom || Author: Drake
# Pistolvania || Author: Vinnie Paz
# Nuthin Left || Author: Judge D
# Young, Wild & Free (feat. Bruno Mars) || Author: Snoop Dogg
# The Way I Am || Author: Eminem
# Perfect Execution || Author: Krayzie Bone
# Forgot About Dre || Author: Dr. Dre
# HeadBand (feat. 2 Chainz) || Author: B.o.B
# I Go Fuckin' Psycho || Author: BLANK
# Enemy (with JID) - from the series Arcane League of Legends || Author: Imagine Dragons
# Go To Church || Author: Ice Cube
# Gun Rule || Author: Ca$his
# N95 || Author: Kendrick Lamar
# Rabbit Run - From "8 Mile" Soundtrack || Author: Eminem
# The Search || Author: NF
# I Don't Like (Remix) || Author: Chief Keef
# Numb || Author: Linkin Park
# Chasing The Dragon Ft Necro || Author: ILL Bill

# %%
reccomendation_list = json_response['tracks']
print(len(reccomendation_list))
# Out:
# 100

# %%
reccomendation_list[0]

# %%
recc_df = pd.DataFrame(reccomendation_list)

# %%
recc_df
# Out:
#                                                 album  \
# 0   {'album_type': 'ALBUM', 'artists': [{'external...
# 1   {'album_type': 'ALBUM', 'artists': [{'external...
# 2   {'album_type': 'ALBUM', 'artists': [{'external...
# 3   {'album_type': 'ALBUM', 'artists': [{'external...
# 4   {'album_type': 'SINGLE', 'artists': [{'externa...
# ..                                                ...
# 95  {'album_type': 'SINGLE', 'artists': [{'externa...
# 96  {'album_type': 'ALBUM', 'artists': [{'external...
# 97  {'album_type': 'ALBUM', 'artists': [{'external...
# 98  {'album_type': 'ALBUM', 'artists': [{'external...
# 99  {'album_type': 'ALBUM', 'artists': [{'external...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# ..                                                ...
# 95  [{'external_urls': {'spotify': 'https://open.s...
# 96  [{'external_urls': {'spotify': 'https://open.s...
# 97  [{'external_urls': {'spotify': 'https://open.s...
# 98  [{'external_urls': {'spotify': 'https://open.s...
# 99  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1   [AD, AE, AG, AL, AM, AO, AR, AU, AZ, BA, BB, B...            1
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3   [AD, AR, AU, BA, BD, BE, BG, BO, BR, CA, CH, C...            1
# 4   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# ..                                                ...          ...
# 95                                           [GB, IE]            1
# 96  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 97  [AM, AT, AU, AZ, BE, BF, BG, BN, BW, BY, CH, C...            1
# 98  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 99  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#     duration_ms  explicit              external_ids  \
# 0        237706      True  {'isrc': 'USIR10500279'}
# 1        186813     False  {'isrc': 'USAT20901852'}
# 2        240053      True  {'isrc': 'USUM70965810'}
# 3        282280     False  {'isrc': 'USUR10001461'}
# 4        254519      True  {'isrc': 'NOMGU1401030'}
# ..          ...       ...                       ...
# 95       190066      True  {'isrc': 'USIR10211627'}
# 96       248053     False  {'isrc': 'USUM71907048'}
# 97       279040     False  {'isrc': 'FR5R00903246'}
# 98       185586     False  {'isrc': 'USWB10300474'}
# 99       244453      True  {'isrc': 'USTC60827945'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/4n...
# 1   {'spotify': 'https://open.spotify.com/track/4C...
# 2   {'spotify': 'https://open.spotify.com/track/6V...
# 3   {'spotify': 'https://open.spotify.com/track/7p...
# 4   {'spotify': 'https://open.spotify.com/track/1g...
# ..                                                ...
# 95  {'spotify': 'https://open.spotify.com/track/64...
# 96  {'spotify': 'https://open.spotify.com/track/3o...
# 97  {'spotify': 'https://open.spotify.com/track/75...
# 98  {'spotify': 'https://open.spotify.com/track/2n...
# 99  {'spotify': 'https://open.spotify.com/track/67...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/4nva9EpKntUT...  4nva9EpKntUTs6CRSGBCn9
# 1   https://api.spotify.com/v1/tracks/4CbKVDZkYKdv...  4CbKVDZkYKdv69I4bCaKUq
# 2   https://api.spotify.com/v1/tracks/6VD2YPeb1P3B...  6VD2YPeb1P3BCP5q0lZHrs
# 3   https://api.spotify.com/v1/tracks/7pypjOgvF6cC...  7pypjOgvF6cCXnHBfmrnC2
# 4   https://api.spotify.com/v1/tracks/1gMFULX8hSzM...  1gMFULX8hSzM1NvbvivH3X
# ..                                                ...                     ...
# 95  https://api.spotify.com/v1/tracks/64sHj6uM3jER...  64sHj6uM3jERhj2gilkBtJ
# 96  https://api.spotify.com/v1/tracks/3oLe5ZILASG8...  3oLe5ZILASG8vU5dxIMfLY
# 97  https://api.spotify.com/v1/tracks/75Bju1SnpiBo...  75Bju1SnpiBoL1PLiVeOOb
# 98  https://api.spotify.com/v1/tracks/2nLtzopw4rPR...  2nLtzopw4rPReszdYBJU6h
# 99  https://api.spotify.com/v1/tracks/67dIc2NvM7b6...  67dIc2NvM7b6GMx1Uc82Y9
#
#     is_local                                   name  popularity  \
# 0      False                         Just A Lil Bit          78
# 1      False                                   Hero          72
# 2      False                                My Time          52
# 3      False                    What If I Was White          40
# 4      False                   Scarface of Facebook          26
# ..       ...                                    ...         ...
# 95     False  Rabbit Run - From "8 Mile" Soundtrack          42
# 96     False                             The Search          75
# 97     False                   I Don't Like (Remix)          54
# 98     False                                   Numb          83
# 99     False            Chasing The Dragon Ft Necro          20
#
#                                           preview_url  track_number   type  \
# 0                                                None            14  track
# 1   https://p.scdn.co/mp3-preview/337b571b3da393ce...             1  track
# 2                                                None             2  track
# 3                                                None            15  track
# 4   https://p.scdn.co/mp3-preview/51452a8708bf94f0...             1  track
# ..                                                ...           ...    ...
# 95                                               None             2  track
# 96                                               None             1  track
# 97                                               None             1  track
# 98  https://p.scdn.co/mp3-preview/48dac3dd8990fbd8...            13  track
# 99  https://p.scdn.co/mp3-preview/9c803d0057249cb8...             8  track
#
#                                      uri
# 0   spotify:track:4nva9EpKntUTs6CRSGBCn9
# 1   spotify:track:4CbKVDZkYKdv69I4bCaKUq
# 2   spotify:track:6VD2YPeb1P3BCP5q0lZHrs
# 3   spotify:track:7pypjOgvF6cCXnHBfmrnC2
# 4   spotify:track:1gMFULX8hSzM1NvbvivH3X
# ..                                   ...
# 95  spotify:track:64sHj6uM3jERhj2gilkBtJ
# 96  spotify:track:3oLe5ZILASG8vU5dxIMfLY
# 97  spotify:track:75Bju1SnpiBoL1PLiVeOOb
# 98  spotify:track:2nLtzopw4rPReszdYBJU6h
# 99  spotify:track:67dIc2NvM7b6GMx1Uc82Y9
#
# [100 rows x 17 columns]

# %%
recc_df2 = recc_df[['name','popularity','explicit','duration_ms']]

# %%
recc_df2
# Out:
#                                      name  popularity  explicit  duration_ms
# 0                          Just A Lil Bit          78      True       237706
# 1                                    Hero          72     False       186813
# 2                                 My Time          52      True       240053
# 3                     What If I Was White          40     False       282280
# 4                    Scarface of Facebook          26      True       254519
# ..                                    ...         ...       ...          ...
# 95  Rabbit Run - From "8 Mile" Soundtrack          42      True       190066
# 96                             The Search          75     False       248053
# 97                   I Don't Like (Remix)          54     False       279040
# 98                                   Numb          83     False       185586
# 99            Chasing The Dragon Ft Necro          20      True       244453
#
# [100 rows x 4 columns]

# %%
recc_df2.dtypes
# Out:
# name           object
# popularity      int64
# explicit         bool
# duration_ms     int64
# dtype: object

# %%
corr = recc_df2.corr()
corr.style.background_gradient().set_precision(5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.lmplot(x='popularity',y='duration_ms',data=recc_df2,col='explicit',palette='Set1', height=8, aspect=1.5, size=5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.lmplot(x='popularity',y='duration_ms',data=recc_df2,hue='explicit',palette='Set1', height=8, aspect=1.5, size=5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
recolist = json_response['tracks']
print(len(recolist))
# Out:
# 18

# %%
uris =[]
for i in json_response['tracks']:
    uris.append(i)
    print(f"\"{i['name']}\" by({i['artists'][0]['name']})")
# Out:
# "Yeah! (feat. Lil Jon & Ludacris)" by(Usher)
# "asBESTos" by(Necro)
# "Can't Be Touched (feat. Mr. Magic & Trouble)" by(Roy Jones Jr.)
# "Nuttin' To Do" by(Bad Meets Evil)
# "Heart Of A Warrior" by(Dizzee Rascal)
# "Outcast" by(Cognito)
# "Step Back!" by(1nonly)
# "Scarface of Facebook" by(Mads Veslelia)
# "Scary Movies" by(Bad Meets Evil)
# "7 MILE BREAD" by(Calik Stillsik)
# "0 To 100 / The Catch Up" by(Drake)
# "Billie Jean 2005" by(Necro)
# "Kill You" by(Eminem)
# "Freestyle (feat. Eminem)" by(DJ Kay Slay)
# "Homicide (feat. Eminem)" by(Logic)
# "Go Hard, Go Home (feat. Giz, Swellz & Choppa)" by(Roy Jones Jr.)
# "Vader" by(King Gordy)
# "Throw It Up" by(Yelawolf)

# %%
recommendation_result = pd.DataFrame(recolist)
recommendation_result
# Out:
#                                                 album  \
# 0   {'album_type': 'ALBUM', 'artists': [{'external...
# 1   {'album_type': 'ALBUM', 'artists': [{'external...
# 2   {'album_type': 'COMPILATION', 'artists': [{'ex...
# 3   {'album_type': 'COMPILATION', 'artists': [{'ex...
# 4   {'album_type': 'ALBUM', 'artists': [{'external...
# 5   {'album_type': 'ALBUM', 'artists': [{'external...
# 6   {'album_type': 'SINGLE', 'artists': [{'externa...
# 7   {'album_type': 'SINGLE', 'artists': [{'externa...
# 8   {'album_type': 'COMPILATION', 'artists': [{'ex...
# 9   {'album_type': 'ALBUM', 'artists': [{'external...
# 10  {'album_type': 'SINGLE', 'artists': [{'externa...
# 11  {'album_type': 'ALBUM', 'artists': [{'external...
# 12  {'album_type': 'ALBUM', 'artists': [{'external...
# 13  {'album_type': 'ALBUM', 'artists': [{'external...
# 14  {'album_type': 'ALBUM', 'artists': [{'external...
# 15  {'album_type': 'COMPILATION', 'artists': [{'ex...
# 16  {'album_type': 'ALBUM', 'artists': [{'external...
# 17  {'album_type': 'ALBUM', 'artists': [{'external...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1   [AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, CM, C...            1
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 5                                            [CA, US]            1
# 6   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 8   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 9   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 10  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 11  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 12  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 13  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 14  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 15  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 16  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 17                                       [CA, MX, US]            1
#
#     duration_ms  explicit              external_ids  \
# 0        250373     False  {'isrc': 'USAR10301423'}
# 1        245880      True  {'isrc': 'USZXT1028393'}
# 2        214400      True  {'isrc': 'TCABF1200656'}
# 3        272826     False  {'isrc': 'USF430610001'}
# 4        194466      True  {'isrc': 'GBUM71303420'}
# 5        258386      True  {'isrc': 'USZXT1002363'}
# 6        150674      True  {'isrc': 'USWB12203894'}
# 7        254519      True  {'isrc': 'NOMGU1401030'}
# 8        228413      True  {'isrc': 'UK8D41406419'}
# 9        250070     False  {'isrc': 'QZFYZ2150624'}
# 10       275226      True  {'isrc': 'USCM51400222'}
# 11       279426      True  {'isrc': 'USQY51295643'}
# 12       264400      True  {'isrc': 'USIR10000580'}
# 13       106533      True  {'isrc': 'USSM10304396'}
# 14       245386      True  {'isrc': 'USUM71908267'}
# 15       325333      True  {'isrc': 'TCABF1200673'}
# 16       219720      True  {'isrc': 'ushm81264562'}
# 17       294400      True  {'isrc': 'USUM71117239'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/5r...
# 1   {'spotify': 'https://open.spotify.com/track/19...
# 2   {'spotify': 'https://open.spotify.com/track/3z...
# 3   {'spotify': 'https://open.spotify.com/track/38...
# 4   {'spotify': 'https://open.spotify.com/track/6X...
# 5   {'spotify': 'https://open.spotify.com/track/02...
# 6   {'spotify': 'https://open.spotify.com/track/6j...
# 7   {'spotify': 'https://open.spotify.com/track/1g...
# 8   {'spotify': 'https://open.spotify.com/track/6p...
# 9   {'spotify': 'https://open.spotify.com/track/1k...
# 10  {'spotify': 'https://open.spotify.com/track/4j...
# 11  {'spotify': 'https://open.spotify.com/track/3W...
# 12  {'spotify': 'https://open.spotify.com/track/5e...
# 13  {'spotify': 'https://open.spotify.com/track/2o...
# 14  {'spotify': 'https://open.spotify.com/track/7M...
# 15  {'spotify': 'https://open.spotify.com/track/0C...
# 16  {'spotify': 'https://open.spotify.com/track/7d...
# 17  {'spotify': 'https://open.spotify.com/track/5l...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/5rb9QrpfcKFH...  5rb9QrpfcKFHM1EUbSIurX
# 1   https://api.spotify.com/v1/tracks/19FR3ew4Mlbn...  19FR3ew4MlbnDpua5Gktxn
# 2   https://api.spotify.com/v1/tracks/3zmduBNsQ6BP...  3zmduBNsQ6BPDTZAkXzG5K
# 3   https://api.spotify.com/v1/tracks/38IQJU3uJGM5...  38IQJU3uJGM55XrI84hlvs
# 4   https://api.spotify.com/v1/tracks/6XUX2rq6SSLk...  6XUX2rq6SSLks9TiZRglFZ
# 5   https://api.spotify.com/v1/tracks/02JLtozAlHmH...  02JLtozAlHmHPBBXjigVBY
# 6   https://api.spotify.com/v1/tracks/6jdwbcH788tx...  6jdwbcH788txYS6Doy1F1j
# 7   https://api.spotify.com/v1/tracks/1gMFULX8hSzM...  1gMFULX8hSzM1NvbvivH3X
# 8   https://api.spotify.com/v1/tracks/6poYzZkWE1DG...  6poYzZkWE1DGI714Ujxzm1
# 9   https://api.spotify.com/v1/tracks/1kVrKvnmttRX...  1kVrKvnmttRXWS5bbnMxOc
# 10  https://api.spotify.com/v1/tracks/4jtyUzZm9WLc...  4jtyUzZm9WLc2AdaJ1dso7
# 11  https://api.spotify.com/v1/tracks/3WcTSEbAbfIo...  3WcTSEbAbfIoEoC24JgKyX
# 12  https://api.spotify.com/v1/tracks/5eGEc27nnhtm...  5eGEc27nnhtmcOh6RC890a
# 13  https://api.spotify.com/v1/tracks/2oFrmDswt3KF...  2oFrmDswt3KFDeXcTf26df
# 14  https://api.spotify.com/v1/tracks/7M2tXmeS15NA...  7M2tXmeS15NAzEn7ABFeBg
# 15  https://api.spotify.com/v1/tracks/0Cw5iiA8OHWI...  0Cw5iiA8OHWIhuIIA8u8N5
# 16  https://api.spotify.com/v1/tracks/7dppTFKnjJV6...  7dppTFKnjJV6UxYKtCuyiE
# 17  https://api.spotify.com/v1/tracks/5lBUY5BqQfbN...  5lBUY5BqQfbNCaMWkVfwpH
#
#     is_local                                           name  popularity  \
# 0      False               Yeah! (feat. Lil Jon & Ludacris)          82
# 1      False                                       asBESTos          19
# 2      False   Can't Be Touched (feat. Mr. Magic & Trouble)          73
# 3      False                                  Nuttin' To Do          34
# 4      False                             Heart Of A Warrior          47
# 5      False                                        Outcast          22
# 6      False                                     Step Back!          76
# 7      False                           Scarface of Facebook          26
# 8      False                                   Scary Movies          43
# 9      False                                   7 MILE BREAD          13
# 10     False                        0 To 100 / The Catch Up          70
# 11     False                               Billie Jean 2005          29
# 12     False                                       Kill You          69
# 13     False                       Freestyle (feat. Eminem)          46
# 14     False                        Homicide (feat. Eminem)          74
# 15     False  Go Hard, Go Home (feat. Giz, Swellz & Choppa)          57
# 16     False                                          Vader          35
# 17     False                                    Throw It Up          41
#
#                                           preview_url  track_number   type  \
# 0   https://p.scdn.co/mp3-preview/775632d9867341c7...             2  track
# 1   https://p.scdn.co/mp3-preview/9e2cba07c1f777ff...             1  track
# 2   https://p.scdn.co/mp3-preview/1d5cc27f2d206a6a...             2  track
# 3   https://p.scdn.co/mp3-preview/57da0e12ab94830c...             1  track
# 4                                                None            12  track
# 5   https://p.scdn.co/mp3-preview/bc05b0602b1752a3...             3  track
# 6   https://p.scdn.co/mp3-preview/c6cd63c9b393a5e1...             1  track
# 7   https://p.scdn.co/mp3-preview/51452a8708bf94f0...             1  track
# 8                                                None             3  track
# 9   https://p.scdn.co/mp3-preview/3afe97e7c943f65a...             2  track
# 10                                               None             1  track
# 11  https://p.scdn.co/mp3-preview/b5c9aad7c6f9df9c...            10  track
# 12                                               None             2  track
# 13  https://p.scdn.co/mp3-preview/88974395f0c83dea...             9  track
# 14                                               None             2  track
# 15  https://p.scdn.co/mp3-preview/18ecb428e7901ede...            13  track
# 16  https://p.scdn.co/mp3-preview/b297c92b4d82b1fe...             4  track
# 17                                               None             6  track
#
#                                      uri
# 0   spotify:track:5rb9QrpfcKFHM1EUbSIurX
# 1   spotify:track:19FR3ew4MlbnDpua5Gktxn
# 2   spotify:track:3zmduBNsQ6BPDTZAkXzG5K
# 3   spotify:track:38IQJU3uJGM55XrI84hlvs
# 4   spotify:track:6XUX2rq6SSLks9TiZRglFZ
# 5   spotify:track:02JLtozAlHmHPBBXjigVBY
# 6   spotify:track:6jdwbcH788txYS6Doy1F1j
# 7   spotify:track:1gMFULX8hSzM1NvbvivH3X
# 8   spotify:track:6poYzZkWE1DGI714Ujxzm1
# 9   spotify:track:1kVrKvnmttRXWS5bbnMxOc
# 10  spotify:track:4jtyUzZm9WLc2AdaJ1dso7
# 11  spotify:track:3WcTSEbAbfIoEoC24JgKyX
# 12  spotify:track:5eGEc27nnhtmcOh6RC890a
# 13  spotify:track:2oFrmDswt3KFDeXcTf26df
# 14  spotify:track:7M2tXmeS15NAzEn7ABFeBg
# 15  spotify:track:0Cw5iiA8OHWIhuIIA8u8N5
# 16  spotify:track:7dppTFKnjJV6UxYKtCuyiE
# 17  spotify:track:5lBUY5BqQfbNCaMWkVfwpH

# %%
reco_df = recommendation_result[['name', 'explicit', 'duration_ms', 'popularity']]

# %%
reco_df
# Out:
#                                              name  explicit  duration_ms  \
# 0                Yeah! (feat. Lil Jon & Ludacris)     False       250373
# 1                                        asBESTos      True       245880
# 2    Can't Be Touched (feat. Mr. Magic & Trouble)      True       214400
# 3                                   Nuttin' To Do     False       272826
# 4                              Heart Of A Warrior      True       194466
# 5                                         Outcast      True       258386
# 6                                      Step Back!      True       150674
# 7                            Scarface of Facebook      True       254519
# 8                                    Scary Movies      True       228413
# 9                                    7 MILE BREAD     False       250070
# 10                        0 To 100 / The Catch Up      True       275226
# 11                               Billie Jean 2005      True       279426
# 12                                       Kill You      True       264400
# 13                       Freestyle (feat. Eminem)      True       106533
# 14                        Homicide (feat. Eminem)      True       245386
# 15  Go Hard, Go Home (feat. Giz, Swellz & Choppa)      True       325333
# 16                                          Vader      True       219720
# 17                                    Throw It Up      True       294400
#
#     popularity
# 0           82
# 1           19
# 2           73
# 3           34
# 4           47
# 5           22
# 6           76
# 7           26
# 8           43
# 9           13
# 10          70
# 11          29
# 12          69
# 13          46
# 14          74
# 15          57
# 16          35
# 17          41

# %%
reco_df.describe()
# Out:
#          duration_ms  popularity
# count      18.000000   18.000000
# mean   240579.500000   47.555556
# std     51215.503871   22.062004
# min    106533.000000   13.000000
# 25%    221893.250000   30.250000
# 50%    250221.500000   44.500000
# 75%    270719.500000   69.750000
# max    325333.000000   82.000000

# %%
reco_df['duration_min'] = round(reco_df['duration_ms'] / 1000, 0)
reco_df["popularity_range"] = reco_df["popularity"] - (reco_df['popularity'].min() - 1)

# %%
reco_df
# Out:
#                                              name  explicit  duration_ms  \
# 0                Yeah! (feat. Lil Jon & Ludacris)     False       250373
# 1                                        asBESTos      True       245880
# 2    Can't Be Touched (feat. Mr. Magic & Trouble)      True       214400
# 3                                   Nuttin' To Do     False       272826
# 4                              Heart Of A Warrior      True       194466
# 5                                         Outcast      True       258386
# 6                                      Step Back!      True       150674
# 7                            Scarface of Facebook      True       254519
# 8                                    Scary Movies      True       228413
# 9                                    7 MILE BREAD     False       250070
# 10                        0 To 100 / The Catch Up      True       275226
# 11                               Billie Jean 2005      True       279426
# 12                                       Kill You      True       264400
# 13                       Freestyle (feat. Eminem)      True       106533
# 14                        Homicide (feat. Eminem)      True       245386
# 15  Go Hard, Go Home (feat. Giz, Swellz & Choppa)      True       325333
# 16                                          Vader      True       219720
# 17                                    Throw It Up      True       294400
#
#     popularity  duration_min  popularity_range
# 0           82         250.0                70
# 1           19         246.0                 7
# 2           73         214.0                61
# 3           34         273.0                22
# 4           47         194.0                35
# 5           22         258.0                10
# 6           76         151.0                64
# 7           26         255.0                14
# 8           43         228.0                31
# 9           13         250.0                 1
# 10          70         275.0                58
# 11          29         279.0                17
# 12          69         264.0                57
# 13          46         107.0                34
# 14          74         245.0                62
# 15          57         325.0                45
# 16          35         220.0                23
# 17          41         294.0                29

# %%
track_data = sp.search(q='track:'+'Believer',type='track', limit=35)

# %%
track_result = []
for i, item in enumerate(track_data['tracks']['items']):
    track = item['album']
    track_id = item['id']
    track_name = item['name']
    popularity = item['popularity']
    track_result.append((i, track['artists'][0]['name'], track['name'], track_id, track_name, track['release_date'], popularity))

# %%
track_result

# %%
track_df = pd.DataFrame(track_result, index=None, columns=('Item', 'Artist', 'Album Name', 'Id', 'Song Name', 'Release Date', 'Popularity'))

# %%
track_df
# Out:
#     Item              Artist  \
# 0      0     Imagine Dragons
# 1      1     Various Artists
# 2      2     Various Artists
# 3      3         The Monkees
# 4      4         The Monkees
# 5      5         Smash Mouth
# 6      6     Imagine Dragons
# 7      7   Twenty One Pilots
# 8      8     Various Artists
# 9      9  The Bouncing Souls
# 10    10     Imagine Dragons
# 11    11         The Monkees
# 12    12        Rhett Walker
# 13    13           Broadside
# 14    14    American Authors
# 15    15        Rhett Walker
# 16    16         Alan Walker
# 17    17     Greta Van Fleet
# 18    18         The Monkees
# 19    19      Above & Beyond
# 20    20       Kidz Bop Kids
# 21    21        3 Doors Down
# 22    22         Smash Mouth
# 23    23          oakwhisper
# 24    24               TWICE
# 25    25            Yelawolf
# 26    26     Various Artists
# 27    27     Various Artists
# 28    28         Major Lazer
# 29    29     Luther Vandross
# 30    30          Emily King
# 31    31     Various Artists
# 32    32       Ozzy Osbourne
# 33    33            ¡MAYDAY!
# 34    34           Wednesday
#
#                                            Album Name                      Id  \
# 0                                              Evolve  0pqnGHJpmpxLKifKRmU6WP
# 1                                      Cleaning Music  1ZOTzqM3qF1mis1w4kI5x2
# 2                                    Pop Trending Hot  0rfvxZivptsuLG9sYQmi6X
# 3                More of The Monkees (Deluxe Edition)  3G7tRC24Uh09Hmp1KZ7LQ2
# 4                  The Birds, The Bees, & The Monkees  7uEcCGtM1FBBGIhPozhJjv
# 5                                         Smash Mouth  1RC5Mb0VhnlhnMlFDnrvE0
# 6                          Believer (feat. Lil Wayne)  2sU9EjevkrU9OkPZudvFNN
# 7                                   Twenty One Pilots  3FvV3j98xtcylQF1drDc9j
# 8                                               Shrek  0mBL2JwjNYKtdFacHxvtJt
# 9                      How I Spent My Summer Vacation  4fRmFVMd0c1SGfzazBJIM8
# 10                           Believer (Kaskade Remix)  6aiHF2IbJr6lG4Vu9em8KF
# 11                            The Best of The Monkees  1CSLeVCXmetBh8IkTPMFdL
# 12                                         Good to Me  1zzyVYQWodZccQYXIa0S9t
# 13                                Into the Raging Sea  1b4ObYUAxvigL7kOw6rBdL
# 14                                    Oh, What A Life  64ybTt8CKxPdeXBNnu08Op
# 15                                           Believer  6n01vQklESLKTMry9VcEFV
# 16                                          Believers  4bMLBGnjAGVFpjAfIkD0UY
# 17                        Anthem Of The Peaceful Army  1AH28vdykcFi8iqPD1TCpg
# 18               More of The Monkees (Deluxe Edition)  4h2jrA7MTbFNk1HK1FYdak
# 19                   Believer (Marsh's Guatape Remix)  1GHOLip5jcgRIBqd8QUx7N
# 20                                        KIDZ BOP 36  3OqNIqo5FS1cBYzkvJCVtD
# 21                                    Time Of My Life  52eLB9JCFxSoSa2m4FWlTW
# 22                                All Star Smash Hits  5M5mzimlah21xlC1rAuIuY
# 23                                           Believer  0c4eF0PfUDAB4UL3PT9e8b
# 24                                     Eyes Wide Open  7louodH5FUYuL3yvHQtq3O
# 25                                        Sometimes Y  2dpmSeMBn8XcpPPHNhEs06
# 26             Can't Take My Eyes off You - 60's Love  1aJYZPJbxmfOdDN6EgZsOZ
# 27             Can't Take My Eyes off You - 60's Love  0DqKoctINeo1omPTLVku5p
# 28                                           Believer  7dFikRPQuLFz4PdCw4ZvCy
# 29                                          Busy Body  1GwsrKwWdhU7iUpaB4eaIn
# 30                                         The Switch  5CnNs7UMthQNuXgFMsQCDX
# 31  Meet the Robinsons (Original Motion Picture So...  26zlrWTl45duRsgdxBin1T
# 32                                  Diary Of A Madman  3RorbkQNdbHrHEURfWWohv
# 33                                          Believers  28MRSuy6PBcR42LbNldzj0
# 34                                      Bull Believer  6wYlN6ikOUsS0PQEI4XJMl
#
#                                             Song Name Release Date  Popularity
# 0                                            Believer   2017-06-23          88
# 1                                            Believer   2022-10-27           0
# 2                                            Believer   2022-10-28           0
# 3                      I'm a Believer - 2006 Remaster   1967-01-09          74
# 4                                   Daydream Believer   1968-04-22          69
# 5                         I'm A Believer - Radio Edit   2001-01-01          60
# 6                          Believer (feat. Lil Wayne)   2019-01-07          64
# 7                                      Oh Ms Believer   2009-12-29          60
# 8   I'm A Believer - From "Shrek" Motion Picture S...   2001-01-01          57
# 9                                      True Believers   2001-05-22          55
# 10                           Believer - Kaskade Remix   2017-06-09          61
# 11                                     I'm a Believer         2003          57
# 12                                           Believer   2020-03-27          51
# 13                                   Foolish Believer   2020-07-24          54
# 14                                           Believer   2014-01-01          51
# 15                                           Believer   2019-05-24          48
# 16                                          Believers   2021-05-14          61
# 17                    Lover, Leaver (Taker, Believer)   2018-10-19          49
# 18      I'm a Believer - Alternate Mix; 2006 Remaster   1967-01-09          56
# 19                   Believer - Marsh's Guatape Remix   2022-01-06          54
# 20                                           Believer   2017-10-13          43
# 21                                           Believer   2011-01-01          54
# 22                        I'm A Believer - Radio Edit   2005-01-01          47
# 23                                           Believer   2022-08-26          46
# 24                                           BELIEVER   2020-10-26          49
# 25                                 Make Me A Believer   2022-03-11          45
# 26                                     I'm a Believer   2022-10-28           0
# 27                     Daydream Believer (45 Version)   2022-10-28           0
# 28                                           Believer   2016-09-30          44
# 29                                 Make Me a Believer   1983-11-25          42
# 30                                           Believer   2015-06-26          41
# 31                                   Another Believer   2007-03-27          41
# 32                                           Believer   1981-11-07          41
# 33                                          Believers   2013-07-16          40
# 34                                      Bull Believer   2022-09-08          40

# %%
features_df = pd.DataFrame()
for id in track_df['Id'].iteritems():
    track_id = id[1]
    audio_features = sp.audio_features(track_id)
    local_features = pd.DataFrame(audio_features, index=[0])
    features_df = features_df.append(local_features)

# %%
features_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.776   0.780   10    -4.374     0       0.1280      0.062200
# 0         0.766   0.775   10    -4.267     0       0.1410      0.050400
# 0         0.766   0.775   10    -4.267     0       0.1410      0.050400
# 0         0.526   0.775    0    -6.050     1       0.0352      0.707000
# 0         0.510   0.488    7   -10.304     1       0.0304      0.256000
# 0         0.559   0.972    6    -3.524     1       0.0639      0.019800
# 0         0.487   0.838   10    -4.319     0       0.2550      0.058000
# 0         0.501   0.328    0    -8.329     1       0.0255      0.612000
# 0         0.515   0.980    6    -2.410     1       0.0701      0.016700
# 0         0.237   0.981    0    -4.320     1       0.0989      0.000296
# 0         0.730   0.634   10    -5.084     0       0.0509      0.181000
# 0         0.502   0.772    0    -6.205     1       0.0322      0.595000
# 0         0.525   0.659    3    -5.992     1       0.0282      0.024900
# 0         0.279   0.963    6    -3.485     1       0.1840      0.026200
# 0         0.583   0.968    1    -2.909     1       0.0368      0.001410
# 0         0.527   0.670    3    -5.073     1       0.0274      0.021500
# 0         0.649   0.690    8    -5.384     0       0.0296      0.024700
# 0         0.505   0.892    4    -4.244     0       0.0377      0.001360
# 0         0.549   0.716    0    -8.387     1       0.0317      0.315000
# 0         0.788   0.786    3    -9.321     0       0.0381      0.084400
# 0         0.821   0.768    0    -4.472     0       0.0813      0.075800
# 0         0.391   0.992    2    -2.661     1       0.0684      0.002570
# 0         0.523   0.973    6    -3.516     1       0.0697      0.017000
# 0         0.678   0.140    4   -14.907     1       0.0703      0.925000
# 0         0.669   0.840    7    -3.176     1       0.0599      0.029400
# 0         0.660   0.790    7    -5.532     1       0.0402      0.000363
# 0         0.502   0.772    0    -6.205     1       0.0322      0.595000
# 0         0.510   0.506    7    -9.177     1       0.0299      0.046100
# 0         0.596   0.905    8    -3.456     0       0.0515      0.074300
# 0         0.453   0.407    8   -11.026     1       0.0314      0.836000
# 0         0.932   0.279    7   -12.933     1       0.1760      0.179000
# 0         0.473   0.630    4    -9.514     1       0.0285      0.093600
# 0         0.323   0.849    5    -6.367     0       0.0694      0.007610
# 0         0.842   0.724    0    -7.097     1       0.1020      0.004720
# 0         0.292   0.581    2    -6.832     1       0.0463      0.007690
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.0810   0.6660  124.949  audio_features
# 0          0.000000    0.1280   0.6950  124.751  audio_features
# 0          0.000000    0.1280   0.6950  124.751  audio_features
# 0          0.000021    0.2170   0.9620   80.106  audio_features
# 0          0.000000    0.1100   0.6490  125.683  audio_features
# 0          0.000006    0.3930   0.9190   82.336  audio_features
# 0          0.000000    0.0645   0.7620   93.701  audio_features
# 0          0.000000    0.1500   0.2630   73.326  audio_features
# 0          0.000000    0.2580   0.9330  164.698  audio_features
# 0          0.000038    0.2020   0.4750   98.181  audio_features
# 0          0.000002    0.1180   0.1820  126.022  audio_features
# 0          0.000002    0.1990   0.9350   79.463  audio_features
# 0          0.000000    0.1240   0.2620   87.065  audio_features
# 0          0.000058    0.1010   0.2180   79.551  audio_features
# 0          0.011500    0.1300   0.9100  119.999  audio_features
# 0          0.000000    0.1570   0.2710   86.999  audio_features
# 0          0.000000    0.1610   0.5930  104.040  audio_features
# 0          0.329000    0.1170   0.5480   91.999  audio_features
# 0          0.000000    0.7300   0.9380   79.193  audio_features
# 0          0.877000    0.1380   0.1570  122.008  audio_features
# 0          0.000000    0.0771   0.5380  124.946  audio_features
# 0          0.010700    0.1560   0.5380  173.886  audio_features
# 0          0.000001    0.3300   0.9310  164.661  audio_features
# 0          0.782000    0.0970   0.4380  120.073  audio_features
# 0          0.000000    0.6630   0.4830  105.009  audio_features
# 0          0.171000    0.1720   0.2280  146.004  audio_features
# 0          0.000002    0.1990   0.9350   79.463  audio_features
# 0          0.000004    0.0886   0.6770  125.687  audio_features
# 0          0.001680    0.1280   0.6920  144.981  audio_features
# 0          0.000074    0.1520   0.2890  134.175  audio_features
# 0          0.198000    0.0810   0.6940  120.002  audio_features
# 0          0.000006    0.1020   0.4030   89.018  audio_features
# 0          0.000330    0.0925   0.3650  100.512  audio_features
# 0          0.000928    0.1530   0.8420  147.976  audio_features
# 0          0.541000    0.0969   0.0765  118.756  audio_features
#
#                        id                                   uri  \
# 0  0pqnGHJpmpxLKifKRmU6WP  spotify:track:0pqnGHJpmpxLKifKRmU6WP
# 0  1ZOTzqM3qF1mis1w4kI5x2  spotify:track:1ZOTzqM3qF1mis1w4kI5x2
# 0  0rfvxZivptsuLG9sYQmi6X  spotify:track:0rfvxZivptsuLG9sYQmi6X
# 0  3G7tRC24Uh09Hmp1KZ7LQ2  spotify:track:3G7tRC24Uh09Hmp1KZ7LQ2
# 0  7uEcCGtM1FBBGIhPozhJjv  spotify:track:7uEcCGtM1FBBGIhPozhJjv
# 0  1RC5Mb0VhnlhnMlFDnrvE0  spotify:track:1RC5Mb0VhnlhnMlFDnrvE0
# 0  2sU9EjevkrU9OkPZudvFNN  spotify:track:2sU9EjevkrU9OkPZudvFNN
# 0  3FvV3j98xtcylQF1drDc9j  spotify:track:3FvV3j98xtcylQF1drDc9j
# 0  0mBL2JwjNYKtdFacHxvtJt  spotify:track:0mBL2JwjNYKtdFacHxvtJt
# 0  4fRmFVMd0c1SGfzazBJIM8  spotify:track:4fRmFVMd0c1SGfzazBJIM8
# 0  6aiHF2IbJr6lG4Vu9em8KF  spotify:track:6aiHF2IbJr6lG4Vu9em8KF
# 0  1CSLeVCXmetBh8IkTPMFdL  spotify:track:1CSLeVCXmetBh8IkTPMFdL
# 0  1zzyVYQWodZccQYXIa0S9t  spotify:track:1zzyVYQWodZccQYXIa0S9t
# 0  1b4ObYUAxvigL7kOw6rBdL  spotify:track:1b4ObYUAxvigL7kOw6rBdL
# 0  64ybTt8CKxPdeXBNnu08Op  spotify:track:64ybTt8CKxPdeXBNnu08Op
# 0  6n01vQklESLKTMry9VcEFV  spotify:track:6n01vQklESLKTMry9VcEFV
# 0  4bMLBGnjAGVFpjAfIkD0UY  spotify:track:4bMLBGnjAGVFpjAfIkD0UY
# 0  1AH28vdykcFi8iqPD1TCpg  spotify:track:1AH28vdykcFi8iqPD1TCpg
# 0  4h2jrA7MTbFNk1HK1FYdak  spotify:track:4h2jrA7MTbFNk1HK1FYdak
# 0  1GHOLip5jcgRIBqd8QUx7N  spotify:track:1GHOLip5jcgRIBqd8QUx7N
# 0  3OqNIqo5FS1cBYzkvJCVtD  spotify:track:3OqNIqo5FS1cBYzkvJCVtD
# 0  52eLB9JCFxSoSa2m4FWlTW  spotify:track:52eLB9JCFxSoSa2m4FWlTW
# 0  5M5mzimlah21xlC1rAuIuY  spotify:track:5M5mzimlah21xlC1rAuIuY
# 0  0c4eF0PfUDAB4UL3PT9e8b  spotify:track:0c4eF0PfUDAB4UL3PT9e8b
# 0  7louodH5FUYuL3yvHQtq3O  spotify:track:7louodH5FUYuL3yvHQtq3O
# 0  2dpmSeMBn8XcpPPHNhEs06  spotify:track:2dpmSeMBn8XcpPPHNhEs06
# 0  1aJYZPJbxmfOdDN6EgZsOZ  spotify:track:1aJYZPJbxmfOdDN6EgZsOZ
# 0  0DqKoctINeo1omPTLVku5p  spotify:track:0DqKoctINeo1omPTLVku5p
# 0  7dFikRPQuLFz4PdCw4ZvCy  spotify:track:7dFikRPQuLFz4PdCw4ZvCy
# 0  1GwsrKwWdhU7iUpaB4eaIn  spotify:track:1GwsrKwWdhU7iUpaB4eaIn
# 0  5CnNs7UMthQNuXgFMsQCDX  spotify:track:5CnNs7UMthQNuXgFMsQCDX
# 0  26zlrWTl45duRsgdxBin1T  spotify:track:26zlrWTl45duRsgdxBin1T
# 0  3RorbkQNdbHrHEURfWWohv  spotify:track:3RorbkQNdbHrHEURfWWohv
# 0  28MRSuy6PBcR42LbNldzj0  spotify:track:28MRSuy6PBcR42LbNldzj0
# 0  6wYlN6ikOUsS0PQEI4XJMl  spotify:track:6wYlN6ikOUsS0PQEI4XJMl
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0pqnGHJpmpxL...
# 0  https://api.spotify.com/v1/tracks/1ZOTzqM3qF1m...
# 0  https://api.spotify.com/v1/tracks/0rfvxZivptsu...
# 0  https://api.spotify.com/v1/tracks/3G7tRC24Uh09...
# 0  https://api.spotify.com/v1/tracks/7uEcCGtM1FBB...
# 0  https://api.spotify.com/v1/tracks/1RC5Mb0Vhnlh...
# 0  https://api.spotify.com/v1/tracks/2sU9EjevkrU9...
# 0  https://api.spotify.com/v1/tracks/3FvV3j98xtcy...
# 0  https://api.spotify.com/v1/tracks/0mBL2JwjNYKt...
# 0  https://api.spotify.com/v1/tracks/4fRmFVMd0c1S...
# 0  https://api.spotify.com/v1/tracks/6aiHF2IbJr6l...
# 0  https://api.spotify.com/v1/tracks/1CSLeVCXmetB...
# 0  https://api.spotify.com/v1/tracks/1zzyVYQWodZc...
# 0  https://api.spotify.com/v1/tracks/1b4ObYUAxvig...
# 0  https://api.spotify.com/v1/tracks/64ybTt8CKxPd...
# 0  https://api.spotify.com/v1/tracks/6n01vQklESLK...
# 0  https://api.spotify.com/v1/tracks/4bMLBGnjAGVF...
# 0  https://api.spotify.com/v1/tracks/1AH28vdykcFi...
# 0  https://api.spotify.com/v1/tracks/4h2jrA7MTbFN...
# 0  https://api.spotify.com/v1/tracks/1GHOLip5jcgR...
# 0  https://api.spotify.com/v1/tracks/3OqNIqo5FS1c...
# 0  https://api.spotify.com/v1/tracks/52eLB9JCFxSo...
# 0  https://api.spotify.com/v1/tracks/5M5mzimlah21...
# 0  https://api.spotify.com/v1/tracks/0c4eF0PfUDAB...
# 0  https://api.spotify.com/v1/tracks/7louodH5FUYu...
# 0  https://api.spotify.com/v1/tracks/2dpmSeMBn8Xc...
# 0  https://api.spotify.com/v1/tracks/1aJYZPJbxmfO...
# 0  https://api.spotify.com/v1/tracks/0DqKoctINeo1...
# 0  https://api.spotify.com/v1/tracks/7dFikRPQuLFz...
# 0  https://api.spotify.com/v1/tracks/1GwsrKwWdhU7...
# 0  https://api.spotify.com/v1/tracks/5CnNs7UMthQN...
# 0  https://api.spotify.com/v1/tracks/26zlrWTl45du...
# 0  https://api.spotify.com/v1/tracks/3RorbkQNdbHr...
# 0  https://api.spotify.com/v1/tracks/28MRSuy6PBcR...
# 0  https://api.spotify.com/v1/tracks/6wYlN6ikOUsS...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0pqn...       204347
# 0  https://api.spotify.com/v1/audio-analysis/1ZOT...       204347
# 0  https://api.spotify.com/v1/audio-analysis/0rfv...       204347
# 0  https://api.spotify.com/v1/audio-analysis/3G7t...       167373
# 0  https://api.spotify.com/v1/audio-analysis/7uEc...       179613
# 0  https://api.spotify.com/v1/audio-analysis/1RC5...       183400
# 0  https://api.spotify.com/v1/audio-analysis/2sU9...       219705
# 0  https://api.spotify.com/v1/audio-analysis/3FvV...       217000
# 0  https://api.spotify.com/v1/audio-analysis/0mBL...       185760
# 0  https://api.spotify.com/v1/audio-analysis/4fRm...       150293
# 0  https://api.spotify.com/v1/audio-analysis/6aiH...       190893
# 0  https://api.spotify.com/v1/audio-analysis/1CSL...       165613
# 0  https://api.spotify.com/v1/audio-analysis/1zzy...       203903
# 0  https://api.spotify.com/v1/audio-analysis/1b4O...       221540
# 0  https://api.spotify.com/v1/audio-analysis/64yb...       183893
# 0  https://api.spotify.com/v1/audio-analysis/6n01...       202943
# 0  https://api.spotify.com/v1/audio-analysis/4bML...       159078
# 0  https://api.spotify.com/v1/audio-analysis/1AH2...       361173
# 0  https://api.spotify.com/v1/audio-analysis/4h2j...       170373
# 0  https://api.spotify.com/v1/audio-analysis/1GHO...       255779
# 0  https://api.spotify.com/v1/audio-analysis/3OqN...       204867
# 0  https://api.spotify.com/v1/audio-analysis/52eL...       178187
# 0  https://api.spotify.com/v1/audio-analysis/5M5m...       183280
# 0  https://api.spotify.com/v1/audio-analysis/0c4e...       131062
# 0  https://api.spotify.com/v1/audio-analysis/7lou...       196947
# 0  https://api.spotify.com/v1/audio-analysis/2dpm...       300480
# 0  https://api.spotify.com/v1/audio-analysis/1aJY...       165613
# 0  https://api.spotify.com/v1/audio-analysis/0DqK...       178893
# 0  https://api.spotify.com/v1/audio-analysis/7dFi...       223469
# 0  https://api.spotify.com/v1/audio-analysis/1Gws...       325960
# 0  https://api.spotify.com/v1/audio-analysis/5CnN...       189536
# 0  https://api.spotify.com/v1/audio-analysis/26zl...       279400
# 0  https://api.spotify.com/v1/audio-analysis/3Ror...       316613
# 0  https://api.spotify.com/v1/audio-analysis/28MR...       185880
# 0  https://api.spotify.com/v1/audio-analysis/6wYl...       510773
#
#    time_signature
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               3
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               3
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4

# %%
final_df = track_df.merge(features_df, left_on="Id", right_on="id")

# %%
final_df
# Out:
#     Item              Artist  \
# 0      0     Imagine Dragons
# 1      1     Various Artists
# 2      2     Various Artists
# 3      3         The Monkees
# 4      4         The Monkees
# 5      5         Smash Mouth
# 6      6     Imagine Dragons
# 7      7   Twenty One Pilots
# 8      8     Various Artists
# 9      9  The Bouncing Souls
# 10    10     Imagine Dragons
# 11    11         The Monkees
# 12    12        Rhett Walker
# 13    13           Broadside
# 14    14    American Authors
# 15    15        Rhett Walker
# 16    16         Alan Walker
# 17    17     Greta Van Fleet
# 18    18         The Monkees
# 19    19      Above & Beyond
# 20    20       Kidz Bop Kids
# 21    21        3 Doors Down
# 22    22         Smash Mouth
# 23    23          oakwhisper
# 24    24               TWICE
# 25    25            Yelawolf
# 26    26     Various Artists
# 27    27     Various Artists
# 28    28         Major Lazer
# 29    29     Luther Vandross
# 30    30          Emily King
# 31    31     Various Artists
# 32    32       Ozzy Osbourne
# 33    33            ¡MAYDAY!
# 34    34           Wednesday
#
#                                            Album Name                      Id  \
# 0                                              Evolve  0pqnGHJpmpxLKifKRmU6WP
# 1                                      Cleaning Music  1ZOTzqM3qF1mis1w4kI5x2
# 2                                    Pop Trending Hot  0rfvxZivptsuLG9sYQmi6X
# 3                More of The Monkees (Deluxe Edition)  3G7tRC24Uh09Hmp1KZ7LQ2
# 4                  The Birds, The Bees, & The Monkees  7uEcCGtM1FBBGIhPozhJjv
# 5                                         Smash Mouth  1RC5Mb0VhnlhnMlFDnrvE0
# 6                          Believer (feat. Lil Wayne)  2sU9EjevkrU9OkPZudvFNN
# 7                                   Twenty One Pilots  3FvV3j98xtcylQF1drDc9j
# 8                                               Shrek  0mBL2JwjNYKtdFacHxvtJt
# 9                      How I Spent My Summer Vacation  4fRmFVMd0c1SGfzazBJIM8
# 10                           Believer (Kaskade Remix)  6aiHF2IbJr6lG4Vu9em8KF
# 11                            The Best of The Monkees  1CSLeVCXmetBh8IkTPMFdL
# 12                                         Good to Me  1zzyVYQWodZccQYXIa0S9t
# 13                                Into the Raging Sea  1b4ObYUAxvigL7kOw6rBdL
# 14                                    Oh, What A Life  64ybTt8CKxPdeXBNnu08Op
# 15                                           Believer  6n01vQklESLKTMry9VcEFV
# 16                                          Believers  4bMLBGnjAGVFpjAfIkD0UY
# 17                        Anthem Of The Peaceful Army  1AH28vdykcFi8iqPD1TCpg
# 18               More of The Monkees (Deluxe Edition)  4h2jrA7MTbFNk1HK1FYdak
# 19                   Believer (Marsh's Guatape Remix)  1GHOLip5jcgRIBqd8QUx7N
# 20                                        KIDZ BOP 36  3OqNIqo5FS1cBYzkvJCVtD
# 21                                    Time Of My Life  52eLB9JCFxSoSa2m4FWlTW
# 22                                All Star Smash Hits  5M5mzimlah21xlC1rAuIuY
# 23                                           Believer  0c4eF0PfUDAB4UL3PT9e8b
# 24                                     Eyes Wide Open  7louodH5FUYuL3yvHQtq3O
# 25                                        Sometimes Y  2dpmSeMBn8XcpPPHNhEs06
# 26             Can't Take My Eyes off You - 60's Love  1aJYZPJbxmfOdDN6EgZsOZ
# 27             Can't Take My Eyes off You - 60's Love  0DqKoctINeo1omPTLVku5p
# 28                                           Believer  7dFikRPQuLFz4PdCw4ZvCy
# 29                                          Busy Body  1GwsrKwWdhU7iUpaB4eaIn
# 30                                         The Switch  5CnNs7UMthQNuXgFMsQCDX
# 31  Meet the Robinsons (Original Motion Picture So...  26zlrWTl45duRsgdxBin1T
# 32                                  Diary Of A Madman  3RorbkQNdbHrHEURfWWohv
# 33                                          Believers  28MRSuy6PBcR42LbNldzj0
# 34                                      Bull Believer  6wYlN6ikOUsS0PQEI4XJMl
#
#                                             Song Name Release Date  \
# 0                                            Believer   2017-06-23
# 1                                            Believer   2022-10-27
# 2                                            Believer   2022-10-28
# 3                      I'm a Believer - 2006 Remaster   1967-01-09
# 4                                   Daydream Believer   1968-04-22
# 5                         I'm A Believer - Radio Edit   2001-01-01
# 6                          Believer (feat. Lil Wayne)   2019-01-07
# 7                                      Oh Ms Believer   2009-12-29
# 8   I'm A Believer - From "Shrek" Motion Picture S...   2001-01-01
# 9                                      True Believers   2001-05-22
# 10                           Believer - Kaskade Remix   2017-06-09
# 11                                     I'm a Believer         2003
# 12                                           Believer   2020-03-27
# 13                                   Foolish Believer   2020-07-24
# 14                                           Believer   2014-01-01
# 15                                           Believer   2019-05-24
# 16                                          Believers   2021-05-14
# 17                    Lover, Leaver (Taker, Believer)   2018-10-19
# 18      I'm a Believer - Alternate Mix; 2006 Remaster   1967-01-09
# 19                   Believer - Marsh's Guatape Remix   2022-01-06
# 20                                           Believer   2017-10-13
# 21                                           Believer   2011-01-01
# 22                        I'm A Believer - Radio Edit   2005-01-01
# 23                                           Believer   2022-08-26
# 24                                           BELIEVER   2020-10-26
# 25                                 Make Me A Believer   2022-03-11
# 26                                     I'm a Believer   2022-10-28
# 27                     Daydream Believer (45 Version)   2022-10-28
# 28                                           Believer   2016-09-30
# 29                                 Make Me a Believer   1983-11-25
# 30                                           Believer   2015-06-26
# 31                                   Another Believer   2007-03-27
# 32                                           Believer   1981-11-07
# 33                                          Believers   2013-07-16
# 34                                      Bull Believer   2022-09-08
#
#     Popularity  danceability  energy  key  ...  liveness  valence    tempo  \
# 0           88         0.776   0.780   10  ...    0.0810   0.6660  124.949
# 1            0         0.766   0.775   10  ...    0.1280   0.6950  124.751
# 2            0         0.766   0.775   10  ...    0.1280   0.6950  124.751
# 3           74         0.526   0.775    0  ...    0.2170   0.9620   80.106
# 4           69         0.510   0.488    7  ...    0.1100   0.6490  125.683
# 5           60         0.559   0.972    6  ...    0.3930   0.9190   82.336
# 6           64         0.487   0.838   10  ...    0.0645   0.7620   93.701
# 7           60         0.501   0.328    0  ...    0.1500   0.2630   73.326
# 8           57         0.515   0.980    6  ...    0.2580   0.9330  164.698
# 9           55         0.237   0.981    0  ...    0.2020   0.4750   98.181
# 10          61         0.730   0.634   10  ...    0.1180   0.1820  126.022
# 11          57         0.502   0.772    0  ...    0.1990   0.9350   79.463
# 12          51         0.525   0.659    3  ...    0.1240   0.2620   87.065
# 13          54         0.279   0.963    6  ...    0.1010   0.2180   79.551
# 14          51         0.583   0.968    1  ...    0.1300   0.9100  119.999
# 15          48         0.527   0.670    3  ...    0.1570   0.2710   86.999
# 16          61         0.649   0.690    8  ...    0.1610   0.5930  104.040
# 17          49         0.505   0.892    4  ...    0.1170   0.5480   91.999
# 18          56         0.549   0.716    0  ...    0.7300   0.9380   79.193
# 19          54         0.788   0.786    3  ...    0.1380   0.1570  122.008
# 20          43         0.821   0.768    0  ...    0.0771   0.5380  124.946
# 21          54         0.391   0.992    2  ...    0.1560   0.5380  173.886
# 22          47         0.523   0.973    6  ...    0.3300   0.9310  164.661
# 23          46         0.678   0.140    4  ...    0.0970   0.4380  120.073
# 24          49         0.669   0.840    7  ...    0.6630   0.4830  105.009
# 25          45         0.660   0.790    7  ...    0.1720   0.2280  146.004
# 26           0         0.502   0.772    0  ...    0.1990   0.9350   79.463
# 27           0         0.510   0.506    7  ...    0.0886   0.6770  125.687
# 28          44         0.596   0.905    8  ...    0.1280   0.6920  144.981
# 29          42         0.453   0.407    8  ...    0.1520   0.2890  134.175
# 30          41         0.932   0.279    7  ...    0.0810   0.6940  120.002
# 31          41         0.473   0.630    4  ...    0.1020   0.4030   89.018
# 32          41         0.323   0.849    5  ...    0.0925   0.3650  100.512
# 33          40         0.842   0.724    0  ...    0.1530   0.8420  147.976
# 34          40         0.292   0.581    2  ...    0.0969   0.0765  118.756
#
#               type                      id  \
# 0   audio_features  0pqnGHJpmpxLKifKRmU6WP
# 1   audio_features  1ZOTzqM3qF1mis1w4kI5x2
# 2   audio_features  0rfvxZivptsuLG9sYQmi6X
# 3   audio_features  3G7tRC24Uh09Hmp1KZ7LQ2
# 4   audio_features  7uEcCGtM1FBBGIhPozhJjv
# 5   audio_features  1RC5Mb0VhnlhnMlFDnrvE0
# 6   audio_features  2sU9EjevkrU9OkPZudvFNN
# 7   audio_features  3FvV3j98xtcylQF1drDc9j
# 8   audio_features  0mBL2JwjNYKtdFacHxvtJt
# 9   audio_features  4fRmFVMd0c1SGfzazBJIM8
# 10  audio_features  6aiHF2IbJr6lG4Vu9em8KF
# 11  audio_features  1CSLeVCXmetBh8IkTPMFdL
# 12  audio_features  1zzyVYQWodZccQYXIa0S9t
# 13  audio_features  1b4ObYUAxvigL7kOw6rBdL
# 14  audio_features  64ybTt8CKxPdeXBNnu08Op
# 15  audio_features  6n01vQklESLKTMry9VcEFV
# 16  audio_features  4bMLBGnjAGVFpjAfIkD0UY
# 17  audio_features  1AH28vdykcFi8iqPD1TCpg
# 18  audio_features  4h2jrA7MTbFNk1HK1FYdak
# 19  audio_features  1GHOLip5jcgRIBqd8QUx7N
# 20  audio_features  3OqNIqo5FS1cBYzkvJCVtD
# 21  audio_features  52eLB9JCFxSoSa2m4FWlTW
# 22  audio_features  5M5mzimlah21xlC1rAuIuY
# 23  audio_features  0c4eF0PfUDAB4UL3PT9e8b
# 24  audio_features  7louodH5FUYuL3yvHQtq3O
# 25  audio_features  2dpmSeMBn8XcpPPHNhEs06
# 26  audio_features  1aJYZPJbxmfOdDN6EgZsOZ
# 27  audio_features  0DqKoctINeo1omPTLVku5p
# 28  audio_features  7dFikRPQuLFz4PdCw4ZvCy
# 29  audio_features  1GwsrKwWdhU7iUpaB4eaIn
# 30  audio_features  5CnNs7UMthQNuXgFMsQCDX
# 31  audio_features  26zlrWTl45duRsgdxBin1T
# 32  audio_features  3RorbkQNdbHrHEURfWWohv
# 33  audio_features  28MRSuy6PBcR42LbNldzj0
# 34  audio_features  6wYlN6ikOUsS0PQEI4XJMl
#
#                                      uri  \
# 0   spotify:track:0pqnGHJpmpxLKifKRmU6WP
# 1   spotify:track:1ZOTzqM3qF1mis1w4kI5x2
# 2   spotify:track:0rfvxZivptsuLG9sYQmi6X
# 3   spotify:track:3G7tRC24Uh09Hmp1KZ7LQ2
# 4   spotify:track:7uEcCGtM1FBBGIhPozhJjv
# 5   spotify:track:1RC5Mb0VhnlhnMlFDnrvE0
# 6   spotify:track:2sU9EjevkrU9OkPZudvFNN
# 7   spotify:track:3FvV3j98xtcylQF1drDc9j
# 8   spotify:track:0mBL2JwjNYKtdFacHxvtJt
# 9   spotify:track:4fRmFVMd0c1SGfzazBJIM8
# 10  spotify:track:6aiHF2IbJr6lG4Vu9em8KF
# 11  spotify:track:1CSLeVCXmetBh8IkTPMFdL
# 12  spotify:track:1zzyVYQWodZccQYXIa0S9t
# 13  spotify:track:1b4ObYUAxvigL7kOw6rBdL
# 14  spotify:track:64ybTt8CKxPdeXBNnu08Op
# 15  spotify:track:6n01vQklESLKTMry9VcEFV
# 16  spotify:track:4bMLBGnjAGVFpjAfIkD0UY
# 17  spotify:track:1AH28vdykcFi8iqPD1TCpg
# 18  spotify:track:4h2jrA7MTbFNk1HK1FYdak
# 19  spotify:track:1GHOLip5jcgRIBqd8QUx7N
# 20  spotify:track:3OqNIqo5FS1cBYzkvJCVtD
# 21  spotify:track:52eLB9JCFxSoSa2m4FWlTW
# 22  spotify:track:5M5mzimlah21xlC1rAuIuY
# 23  spotify:track:0c4eF0PfUDAB4UL3PT9e8b
# 24  spotify:track:7louodH5FUYuL3yvHQtq3O
# 25  spotify:track:2dpmSeMBn8XcpPPHNhEs06
# 26  spotify:track:1aJYZPJbxmfOdDN6EgZsOZ
# 27  spotify:track:0DqKoctINeo1omPTLVku5p
# 28  spotify:track:7dFikRPQuLFz4PdCw4ZvCy
# 29  spotify:track:1GwsrKwWdhU7iUpaB4eaIn
# 30  spotify:track:5CnNs7UMthQNuXgFMsQCDX
# 31  spotify:track:26zlrWTl45duRsgdxBin1T
# 32  spotify:track:3RorbkQNdbHrHEURfWWohv
# 33  spotify:track:28MRSuy6PBcR42LbNldzj0
# 34  spotify:track:6wYlN6ikOUsS0PQEI4XJMl
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/0pqnGHJpmpxL...
# 1   https://api.spotify.com/v1/tracks/1ZOTzqM3qF1m...
# 2   https://api.spotify.com/v1/tracks/0rfvxZivptsu...
# 3   https://api.spotify.com/v1/tracks/3G7tRC24Uh09...
# 4   https://api.spotify.com/v1/tracks/7uEcCGtM1FBB...
# 5   https://api.spotify.com/v1/tracks/1RC5Mb0Vhnlh...
# 6   https://api.spotify.com/v1/tracks/2sU9EjevkrU9...
# 7   https://api.spotify.com/v1/tracks/3FvV3j98xtcy...
# 8   https://api.spotify.com/v1/tracks/0mBL2JwjNYKt...
# 9   https://api.spotify.com/v1/tracks/4fRmFVMd0c1S...
# 10  https://api.spotify.com/v1/tracks/6aiHF2IbJr6l...
# 11  https://api.spotify.com/v1/tracks/1CSLeVCXmetB...
# 12  https://api.spotify.com/v1/tracks/1zzyVYQWodZc...
# 13  https://api.spotify.com/v1/tracks/1b4ObYUAxvig...
# 14  https://api.spotify.com/v1/tracks/64ybTt8CKxPd...
# 15  https://api.spotify.com/v1/tracks/6n01vQklESLK...
# 16  https://api.spotify.com/v1/tracks/4bMLBGnjAGVF...
# 17  https://api.spotify.com/v1/tracks/1AH28vdykcFi...
# 18  https://api.spotify.com/v1/tracks/4h2jrA7MTbFN...
# 19  https://api.spotify.com/v1/tracks/1GHOLip5jcgR...
# 20  https://api.spotify.com/v1/tracks/3OqNIqo5FS1c...
# 21  https://api.spotify.com/v1/tracks/52eLB9JCFxSo...
# 22  https://api.spotify.com/v1/tracks/5M5mzimlah21...
# 23  https://api.spotify.com/v1/tracks/0c4eF0PfUDAB...
# 24  https://api.spotify.com/v1/tracks/7louodH5FUYu...
# 25  https://api.spotify.com/v1/tracks/2dpmSeMBn8Xc...
# 26  https://api.spotify.com/v1/tracks/1aJYZPJbxmfO...
# 27  https://api.spotify.com/v1/tracks/0DqKoctINeo1...
# 28  https://api.spotify.com/v1/tracks/7dFikRPQuLFz...
# 29  https://api.spotify.com/v1/tracks/1GwsrKwWdhU7...
# 30  https://api.spotify.com/v1/tracks/5CnNs7UMthQN...
# 31  https://api.spotify.com/v1/tracks/26zlrWTl45du...
# 32  https://api.spotify.com/v1/tracks/3RorbkQNdbHr...
# 33  https://api.spotify.com/v1/tracks/28MRSuy6PBcR...
# 34  https://api.spotify.com/v1/tracks/6wYlN6ikOUsS...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/0pqn...      204347
# 1   https://api.spotify.com/v1/audio-analysis/1ZOT...      204347
# 2   https://api.spotify.com/v1/audio-analysis/0rfv...      204347
# 3   https://api.spotify.com/v1/audio-analysis/3G7t...      167373
# 4   https://api.spotify.com/v1/audio-analysis/7uEc...      179613
# 5   https://api.spotify.com/v1/audio-analysis/1RC5...      183400
# 6   https://api.spotify.com/v1/audio-analysis/2sU9...      219705
# 7   https://api.spotify.com/v1/audio-analysis/3FvV...      217000
# 8   https://api.spotify.com/v1/audio-analysis/0mBL...      185760
# 9   https://api.spotify.com/v1/audio-analysis/4fRm...      150293
# 10  https://api.spotify.com/v1/audio-analysis/6aiH...      190893
# 11  https://api.spotify.com/v1/audio-analysis/1CSL...      165613
# 12  https://api.spotify.com/v1/audio-analysis/1zzy...      203903
# 13  https://api.spotify.com/v1/audio-analysis/1b4O...      221540
# 14  https://api.spotify.com/v1/audio-analysis/64yb...      183893
# 15  https://api.spotify.com/v1/audio-analysis/6n01...      202943
# 16  https://api.spotify.com/v1/audio-analysis/4bML...      159078
# 17  https://api.spotify.com/v1/audio-analysis/1AH2...      361173
# 18  https://api.spotify.com/v1/audio-analysis/4h2j...      170373
# 19  https://api.spotify.com/v1/audio-analysis/1GHO...      255779
# 20  https://api.spotify.com/v1/audio-analysis/3OqN...      204867
# 21  https://api.spotify.com/v1/audio-analysis/52eL...      178187
# 22  https://api.spotify.com/v1/audio-analysis/5M5m...      183280
# 23  https://api.spotify.com/v1/audio-analysis/0c4e...      131062
# 24  https://api.spotify.com/v1/audio-analysis/7lou...      196947
# 25  https://api.spotify.com/v1/audio-analysis/2dpm...      300480
# 26  https://api.spotify.com/v1/audio-analysis/1aJY...      165613
# 27  https://api.spotify.com/v1/audio-analysis/0DqK...      178893
# 28  https://api.spotify.com/v1/audio-analysis/7dFi...      223469
# 29  https://api.spotify.com/v1/audio-analysis/1Gws...      325960
# 30  https://api.spotify.com/v1/audio-analysis/5CnN...      189536
# 31  https://api.spotify.com/v1/audio-analysis/26zl...      279400
# 32  https://api.spotify.com/v1/audio-analysis/3Ror...      316613
# 33  https://api.spotify.com/v1/audio-analysis/28MR...      185880
# 34  https://api.spotify.com/v1/audio-analysis/6wYl...      510773
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               3
# 7               4
# 8               4
# 9               4
# 10              4
# 11              4
# 12              4
# 13              4
# 14              4
# 15              4
# 16              4
# 17              4
# 18              4
# 19              4
# 20              4
# 21              4
# 22              4
# 23              3
# 24              4
# 25              4
# 26              4
# 27              4
# 28              4
# 29              4
# 30              4
# 31              4
# 32              4
# 33              4
# 34              4
#
# [35 rows x 25 columns]

# %%
feature_name = "liveness"
final_df_sorted = final_df.sort_values(by=['Popularity'], ascending=False)
df_plot = final_df_sorted[['Artist', 'Album Name', 'Song Name', 'Release Date', 'Popularity', f'{feature_name}']]

# %%
df_plot
# Out:
#                 Artist                                         Album Name  \
# 0      Imagine Dragons                                             Evolve
# 3          The Monkees               More of The Monkees (Deluxe Edition)
# 4          The Monkees                 The Birds, The Bees, & The Monkees
# 6      Imagine Dragons                         Believer (feat. Lil Wayne)
# 16         Alan Walker                                          Believers
# 10     Imagine Dragons                           Believer (Kaskade Remix)
# 5          Smash Mouth                                        Smash Mouth
# 7    Twenty One Pilots                                  Twenty One Pilots
# 11         The Monkees                            The Best of The Monkees
# 8      Various Artists                                              Shrek
# 18         The Monkees               More of The Monkees (Deluxe Edition)
# 9   The Bouncing Souls                     How I Spent My Summer Vacation
# 13           Broadside                                Into the Raging Sea
# 21        3 Doors Down                                    Time Of My Life
# 19      Above & Beyond                   Believer (Marsh's Guatape Remix)
# 12        Rhett Walker                                         Good to Me
# 14    American Authors                                    Oh, What A Life
# 24               TWICE                                     Eyes Wide Open
# 17     Greta Van Fleet                        Anthem Of The Peaceful Army
# 15        Rhett Walker                                           Believer
# 22         Smash Mouth                                All Star Smash Hits
# 23          oakwhisper                                           Believer
# 25            Yelawolf                                        Sometimes Y
# 28         Major Lazer                                           Believer
# 20       Kidz Bop Kids                                        KIDZ BOP 36
# 29     Luther Vandross                                          Busy Body
# 30          Emily King                                         The Switch
# 31     Various Artists  Meet the Robinsons (Original Motion Picture So...
# 32       Ozzy Osbourne                                  Diary Of A Madman
# 33            ¡MAYDAY!                                          Believers
# 34           Wednesday                                      Bull Believer
# 1      Various Artists                                     Cleaning Music
# 2      Various Artists                                   Pop Trending Hot
# 26     Various Artists             Can't Take My Eyes off You - 60's Love
# 27     Various Artists             Can't Take My Eyes off You - 60's Love
#
#                                             Song Name Release Date  \
# 0                                            Believer   2017-06-23
# 3                      I'm a Believer - 2006 Remaster   1967-01-09
# 4                                   Daydream Believer   1968-04-22
# 6                          Believer (feat. Lil Wayne)   2019-01-07
# 16                                          Believers   2021-05-14
# 10                           Believer - Kaskade Remix   2017-06-09
# 5                         I'm A Believer - Radio Edit   2001-01-01
# 7                                      Oh Ms Believer   2009-12-29
# 11                                     I'm a Believer         2003
# 8   I'm A Believer - From "Shrek" Motion Picture S...   2001-01-01
# 18      I'm a Believer - Alternate Mix; 2006 Remaster   1967-01-09
# 9                                      True Believers   2001-05-22
# 13                                   Foolish Believer   2020-07-24
# 21                                           Believer   2011-01-01
# 19                   Believer - Marsh's Guatape Remix   2022-01-06
# 12                                           Believer   2020-03-27
# 14                                           Believer   2014-01-01
# 24                                           BELIEVER   2020-10-26
# 17                    Lover, Leaver (Taker, Believer)   2018-10-19
# 15                                           Believer   2019-05-24
# 22                        I'm A Believer - Radio Edit   2005-01-01
# 23                                           Believer   2022-08-26
# 25                                 Make Me A Believer   2022-03-11
# 28                                           Believer   2016-09-30
# 20                                           Believer   2017-10-13
# 29                                 Make Me a Believer   1983-11-25
# 30                                           Believer   2015-06-26
# 31                                   Another Believer   2007-03-27
# 32                                           Believer   1981-11-07
# 33                                          Believers   2013-07-16
# 34                                      Bull Believer   2022-09-08
# 1                                            Believer   2022-10-27
# 2                                            Believer   2022-10-28
# 26                                     I'm a Believer   2022-10-28
# 27                     Daydream Believer (45 Version)   2022-10-28
#
#     Popularity  liveness
# 0           88    0.0810
# 3           74    0.2170
# 4           69    0.1100
# 6           64    0.0645
# 16          61    0.1610
# 10          61    0.1180
# 5           60    0.3930
# 7           60    0.1500
# 11          57    0.1990
# 8           57    0.2580
# 18          56    0.7300
# 9           55    0.2020
# 13          54    0.1010
# 21          54    0.1560
# 19          54    0.1380
# 12          51    0.1240
# 14          51    0.1300
# 24          49    0.6630
# 17          49    0.1170
# 15          48    0.1570
# 22          47    0.3300
# 23          46    0.0970
# 25          45    0.1720
# 28          44    0.1280
# 20          43    0.0771
# 29          42    0.1520
# 30          41    0.0810
# 31          41    0.1020
# 32          41    0.0925
# 33          40    0.1530
# 34          40    0.0969
# 1            0    0.1280
# 2            0    0.1280
# 26           0    0.1990
# 27           0    0.0886

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.figure(figsize=(15, 6), facecolor=(.9, .9, .9))
    
x = df_plot['Song Name']
y = df_plot[feature_name]
s = df_plot['Popularity']*30

plt.scatter(x, y, s, alpha=0.7, c=df_plot[feature_name])
plt.xticks(rotation=90)
plt.legend()
# show the graph
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
artist_name = 'shawn mendes'
artists = sp.search(q='artist:'+artist_name,type='artist', limit=10)

# %%
artists
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3Ashawn+mendes&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#     'followers': {'href': None, 'total': 39609100},
#     'genres': ['canadian pop', 'dance pop', 'pop', 'viral pop'],
#     'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#     'id': '7n2wHs1TKAczGzO7Dd2rGr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb46e7a06fa6dfefaed6a3f0db',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517446e7a06fa6dfefaed6a3f0db',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17846e7a06fa6dfefaed6a3f0db',
#       'width': 160}],
#     'name': 'Shawn Mendes',
#     'popularity': 84,
#     'type': 'artist',
#     'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4pjjRVF9bZ8y9iXIuVgOam'},
#     'followers': {'href': None, 'total': 1670},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4pjjRVF9bZ8y9iXIuVgOam',
#     'id': '4pjjRVF9bZ8y9iXIuVgOam',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27311093c550c588b1d7b28f14a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0211093c550c588b1d7b28f14a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485111093c550c588b1d7b28f14a',
#       'width': 64}],
#     'name': 'MENDES SHAWN',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:4pjjRVF9bZ8y9iXIuVgOam'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0b5wYt45JvDbkGvX8JRymQ'},
#     'followers': {'href': None, 'total': 19},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0b5wYt45JvDbkGvX8JRymQ',
#     'id': '0b5wYt45JvDbkGvX8JRymQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27316a37c20f7ecc23e1df395eb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0216a37c20f7ecc23e1df395eb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485116a37c20f7ecc23e1df395eb',
#       'width': 64}],
#     'name': 'Cortana Flutist & Shawn Mendes',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:0b5wYt45JvDbkGvX8JRymQ'}],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 3}}

# %%
artist_uri = artists['artists']['items'][0]['uri']
results = sp.artist_top_tracks(artist_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    if track['preview_url'] is not None:
        print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : There's Nothing Holdin' Me Back
# cover art: https://i.scdn.co/image/ab67616d0000b273ea3ef7697cfd5705b8f47521
#
# track    : Treat You Better
# cover art: https://i.scdn.co/image/ab67616d0000b2731376b4b16f4bfcba02dc571b
#
# track    : Mercy
# cover art: https://i.scdn.co/image/ab67616d0000b273ea3ef7697cfd5705b8f47521
#
# track    : When You're Gone
# cover art: https://i.scdn.co/image/ab67616d0000b273dad0775943c1a826bfed3117
#
# track    : Summer of Love (Shawn Mendes & Tainy)
# cover art: https://i.scdn.co/image/ab67616d0000b273a111c87c210cc9bff93948bd
#
# track    : Señorita
# cover art: https://i.scdn.co/image/ab67616d0000b273c820f033bd82bef4355d1563
#
# track    : Stitches
# cover art: https://i.scdn.co/image/ab67616d0000b273d26246b23c8bfa8ce543b3bb
#
# track    : It'll Be Okay
# cover art: https://i.scdn.co/image/ab67616d0000b27372355b30dde4b6ded10ef48c
#
# track    : KESI - Remix
# audio    : https://p.scdn.co/mp3-preview/c93653b9309af7439422a3e620a242145a5ec8ea?cid=a9c08768bf6f4d5083cdafbbf17c2277
# cover art: https://i.scdn.co/image/ab67616d0000b273bec684438c0610c1caab0198
#
# track    : In My Blood
# cover art: https://i.scdn.co/image/ab67616d0000b273269423eb6467e308c0fbce24

# %%
track_result = []
for i, item in enumerate(results['tracks']):
#     track = item['album']
    track_id = item['id']
    track_name = item['name']
    popularity = item['popularity']
    track_result.append((i, artist_name, track['name'], track_id, track_name, item['album']['release_date'], popularity))

# %%
track_result
# Out:
# [(0,
#   'shawn mendes',
#   'In My Blood',
#   '7JJmb5XwzOO8jgpou264Ml',
#   "There's Nothing Holdin' Me Back",
#   '2017-04-20',
#   86),
#  (1,
#   'shawn mendes',
#   'In My Blood',
#   '3QGsuHI8jO1Rx4JWLUh9jd',
#   'Treat You Better',
#   '2017-04-20',
#   84),
#  (2,
#   'shawn mendes',
#   'In My Blood',
#   '0AS63m1wHv9n4VVRizK6Hc',
#   'Mercy',
#   '2017-04-20',
#   81),
#  (3,
#   'shawn mendes',
#   'In My Blood',
#   '0U1W2LZVUX7qTm7dDpqxh6',
#   "When You're Gone",
#   '2022-03-31',
#   81),
#  (4,
#   'shawn mendes',
#   'In My Blood',
#   '0z8hI3OPS8ADPWtoCjjLl6',
#   'Summer of Love (Shawn Mendes & Tainy)',
#   '2021-08-20',
#   81),
#  (5,
#   'shawn mendes',
#   'In My Blood',
#   '6v3KW9xbzN5yKLt9YKDYA2',
#   'Señorita',
#   '2019-06-19',
#   80),
#  (6,
#   'shawn mendes',
#   'In My Blood',
#   '5jsw9uXEGuKyJzs0boZ1bT',
#   'Stitches',
#   '2015-04-14',
#   75),
#  (7,
#   'shawn mendes',
#   'In My Blood',
#   '2KnLkZ3z7PO3kgVGHGqDpD',
#   "It'll Be Okay",
#   '2021-12-01',
#   79),
#  (8,
#   'shawn mendes',
#   'In My Blood',
#   '0IqCoZ168iRc9LqfrYgpZy',
#   'KESI - Remix',
#   '2021-07-14',
#   75),
#  (9,
#   'shawn mendes',
#   'In My Blood',
#   '2QZ7WLBE8h2y1Y5Fb8RYbH',
#   'In My Blood',
#   '2018-05-25',
#   75)]

# %%
track_df = pd.DataFrame(track_result, index=None, columns=('Item', 'Artist', 'Album Name', 'Id', 'Song Name', 'Release Date', 'Popularity'))

# %%
features_df = pd.DataFrame()
for id in track_df['Id'].iteritems():
    track_id = id[1]
    audio_features = sp.audio_features(track_id)
    local_features = pd.DataFrame(audio_features, index=[0])
    features_df = features_df.append(local_features)

# %%
features_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.866   0.813   11    -4.063     0       0.0554        0.3800
# 0         0.444   0.819   10    -4.078     0       0.3410        0.1060
# 0         0.555   0.662   11    -4.952     0       0.0827        0.1250
# 0         0.603   0.691    5    -5.805     1       0.0372        0.0248
# 0         0.776   0.808   11    -4.501     1       0.1170        0.0297
# 0         0.759   0.548    9    -6.049     0       0.0290        0.0392
# 0         0.752   0.754    1    -6.684     1       0.0615        0.0151
# 0         0.398   0.286    7   -11.881     1       0.0330        0.6160
# 0         0.871   0.815    4    -4.439     1       0.0477        0.1270
# 0         0.622   0.712    5    -7.321     1       0.0660        0.0573
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.0779   0.9690  121.998  audio_features
# 0          0.000000    0.1070   0.7470   82.695  audio_features
# 0          0.000000    0.1110   0.3560  148.128  audio_features
# 0          0.000000    0.5830   0.5770  147.148  audio_features
# 0          0.000127    0.1030   0.4940  123.988  audio_features
# 0          0.000000    0.0828   0.7490  116.967  audio_features
# 0          0.000000    0.0486   0.7550  149.789  audio_features
# 0          0.000146    0.0912   0.0666   78.262  audio_features
# 0          0.000006    0.0940   0.8230  122.959  audio_features
# 0          0.000000    0.1300   0.4870  140.025  audio_features
#
#                        id                                   uri  \
# 0  7JJmb5XwzOO8jgpou264Ml  spotify:track:7JJmb5XwzOO8jgpou264Ml
# 0  3QGsuHI8jO1Rx4JWLUh9jd  spotify:track:3QGsuHI8jO1Rx4JWLUh9jd
# 0  0AS63m1wHv9n4VVRizK6Hc  spotify:track:0AS63m1wHv9n4VVRizK6Hc
# 0  0U1W2LZVUX7qTm7dDpqxh6  spotify:track:0U1W2LZVUX7qTm7dDpqxh6
# 0  0z8hI3OPS8ADPWtoCjjLl6  spotify:track:0z8hI3OPS8ADPWtoCjjLl6
# 0  6v3KW9xbzN5yKLt9YKDYA2  spotify:track:6v3KW9xbzN5yKLt9YKDYA2
# 0  5jsw9uXEGuKyJzs0boZ1bT  spotify:track:5jsw9uXEGuKyJzs0boZ1bT
# 0  2KnLkZ3z7PO3kgVGHGqDpD  spotify:track:2KnLkZ3z7PO3kgVGHGqDpD
# 0  0IqCoZ168iRc9LqfrYgpZy  spotify:track:0IqCoZ168iRc9LqfrYgpZy
# 0  2QZ7WLBE8h2y1Y5Fb8RYbH  spotify:track:2QZ7WLBE8h2y1Y5Fb8RYbH
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7JJmb5XwzOO8...
# 0  https://api.spotify.com/v1/tracks/3QGsuHI8jO1R...
# 0  https://api.spotify.com/v1/tracks/0AS63m1wHv9n...
# 0  https://api.spotify.com/v1/tracks/0U1W2LZVUX7q...
# 0  https://api.spotify.com/v1/tracks/0z8hI3OPS8AD...
# 0  https://api.spotify.com/v1/tracks/6v3KW9xbzN5y...
# 0  https://api.spotify.com/v1/tracks/5jsw9uXEGuKy...
# 0  https://api.spotify.com/v1/tracks/2KnLkZ3z7PO3...
# 0  https://api.spotify.com/v1/tracks/0IqCoZ168iRc...
# 0  https://api.spotify.com/v1/tracks/2QZ7WLBE8h2y...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7JJm...       199440
# 0  https://api.spotify.com/v1/audio-analysis/3QGs...       187973
# 0  https://api.spotify.com/v1/audio-analysis/0AS6...       208733
# 0  https://api.spotify.com/v1/audio-analysis/0U1W...       172267
# 0  https://api.spotify.com/v1/audio-analysis/0z8h...       184104
# 0  https://api.spotify.com/v1/audio-analysis/6v3K...       190800
# 0  https://api.spotify.com/v1/audio-analysis/5jsw...       206880
# 0  https://api.spotify.com/v1/audio-analysis/2KnL...       222800
# 0  https://api.spotify.com/v1/audio-analysis/0IqC...       176575
# 0  https://api.spotify.com/v1/audio-analysis/2QZ7...       211360
#
#    time_signature
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4

# %%
final_df = track_df.merge(features_df, left_on="Id", right_on="id")

# %%
final_df
# Out:
#    Item        Artist   Album Name                      Id  \
# 0     0  shawn mendes  In My Blood  7JJmb5XwzOO8jgpou264Ml
# 1     1  shawn mendes  In My Blood  3QGsuHI8jO1Rx4JWLUh9jd
# 2     2  shawn mendes  In My Blood  0AS63m1wHv9n4VVRizK6Hc
# 3     3  shawn mendes  In My Blood  0U1W2LZVUX7qTm7dDpqxh6
# 4     4  shawn mendes  In My Blood  0z8hI3OPS8ADPWtoCjjLl6
# 5     5  shawn mendes  In My Blood  6v3KW9xbzN5yKLt9YKDYA2
# 6     6  shawn mendes  In My Blood  5jsw9uXEGuKyJzs0boZ1bT
# 7     7  shawn mendes  In My Blood  2KnLkZ3z7PO3kgVGHGqDpD
# 8     8  shawn mendes  In My Blood  0IqCoZ168iRc9LqfrYgpZy
# 9     9  shawn mendes  In My Blood  2QZ7WLBE8h2y1Y5Fb8RYbH
#
#                                Song Name Release Date  Popularity  \
# 0        There's Nothing Holdin' Me Back   2017-04-20          86
# 1                       Treat You Better   2017-04-20          84
# 2                                  Mercy   2017-04-20          81
# 3                       When You're Gone   2022-03-31          81
# 4  Summer of Love (Shawn Mendes & Tainy)   2021-08-20          81
# 5                               Señorita   2019-06-19          80
# 6                               Stitches   2015-04-14          75
# 7                          It'll Be Okay   2021-12-01          79
# 8                           KESI - Remix   2021-07-14          75
# 9                            In My Blood   2018-05-25          75
#
#    danceability  energy  key  ...  liveness  valence    tempo            type  \
# 0         0.866   0.813   11  ...    0.0779   0.9690  121.998  audio_features
# 1         0.444   0.819   10  ...    0.1070   0.7470   82.695  audio_features
# 2         0.555   0.662   11  ...    0.1110   0.3560  148.128  audio_features
# 3         0.603   0.691    5  ...    0.5830   0.5770  147.148  audio_features
# 4         0.776   0.808   11  ...    0.1030   0.4940  123.988  audio_features
# 5         0.759   0.548    9  ...    0.0828   0.7490  116.967  audio_features
# 6         0.752   0.754    1  ...    0.0486   0.7550  149.789  audio_features
# 7         0.398   0.286    7  ...    0.0912   0.0666   78.262  audio_features
# 8         0.871   0.815    4  ...    0.0940   0.8230  122.959  audio_features
# 9         0.622   0.712    5  ...    0.1300   0.4870  140.025  audio_features
#
#                        id                                   uri  \
# 0  7JJmb5XwzOO8jgpou264Ml  spotify:track:7JJmb5XwzOO8jgpou264Ml
# 1  3QGsuHI8jO1Rx4JWLUh9jd  spotify:track:3QGsuHI8jO1Rx4JWLUh9jd
# 2  0AS63m1wHv9n4VVRizK6Hc  spotify:track:0AS63m1wHv9n4VVRizK6Hc
# 3  0U1W2LZVUX7qTm7dDpqxh6  spotify:track:0U1W2LZVUX7qTm7dDpqxh6
# 4  0z8hI3OPS8ADPWtoCjjLl6  spotify:track:0z8hI3OPS8ADPWtoCjjLl6
# 5  6v3KW9xbzN5yKLt9YKDYA2  spotify:track:6v3KW9xbzN5yKLt9YKDYA2
# 6  5jsw9uXEGuKyJzs0boZ1bT  spotify:track:5jsw9uXEGuKyJzs0boZ1bT
# 7  2KnLkZ3z7PO3kgVGHGqDpD  spotify:track:2KnLkZ3z7PO3kgVGHGqDpD
# 8  0IqCoZ168iRc9LqfrYgpZy  spotify:track:0IqCoZ168iRc9LqfrYgpZy
# 9  2QZ7WLBE8h2y1Y5Fb8RYbH  spotify:track:2QZ7WLBE8h2y1Y5Fb8RYbH
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7JJmb5XwzOO8...
# 1  https://api.spotify.com/v1/tracks/3QGsuHI8jO1R...
# 2  https://api.spotify.com/v1/tracks/0AS63m1wHv9n...
# 3  https://api.spotify.com/v1/tracks/0U1W2LZVUX7q...
# 4  https://api.spotify.com/v1/tracks/0z8hI3OPS8AD...
# 5  https://api.spotify.com/v1/tracks/6v3KW9xbzN5y...
# 6  https://api.spotify.com/v1/tracks/5jsw9uXEGuKy...
# 7  https://api.spotify.com/v1/tracks/2KnLkZ3z7PO3...
# 8  https://api.spotify.com/v1/tracks/0IqCoZ168iRc...
# 9  https://api.spotify.com/v1/tracks/2QZ7WLBE8h2y...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7JJm...      199440
# 1  https://api.spotify.com/v1/audio-analysis/3QGs...      187973
# 2  https://api.spotify.com/v1/audio-analysis/0AS6...      208733
# 3  https://api.spotify.com/v1/audio-analysis/0U1W...      172267
# 4  https://api.spotify.com/v1/audio-analysis/0z8h...      184104
# 5  https://api.spotify.com/v1/audio-analysis/6v3K...      190800
# 6  https://api.spotify.com/v1/audio-analysis/5jsw...      206880
# 7  https://api.spotify.com/v1/audio-analysis/2KnL...      222800
# 8  https://api.spotify.com/v1/audio-analysis/0IqC...      176575
# 9  https://api.spotify.com/v1/audio-analysis/2QZ7...      211360
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
# 5              4
# 6              4
# 7              4
# 8              4
# 9              4
#
# [10 rows x 25 columns]
